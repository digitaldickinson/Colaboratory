# %% [markdown]
# <a href="https://colab.research.google.com/github/digitaldickinson/Colaboratory/blob/master/Grabbing_JSON_data_from_Parliament_petitions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Grabbing JSON data from Parliament petitions (no, not that one!)
# We are going to start with two libraries for this one.
#  - Requests -  a library to access and process web page requests and store the results.
#  - Pandas - to manage and analyse the data

# %%
import requests
import pandas as pd

# %% [markdown]
# We are going to use the petition "[People found with a knife to get 10 years and using a knife 25 years in prison](https://petition.parliament.uk/petitions/233926)". The petitions website lets you see the raw data for the petition in JSON format. JSON or JavaScript Object Notation is way of storing data that is (so they claim) human as well as machine readable. In practice this means its stored as text. But there is a structure.  Here's an example of a line of data from the petition:
#
# `
# {"name":"Glasgow North East","ons_code":"S14000032","mp":"Mr Paul Sweeney MP","signature_count":14},{"name":"Glasgow North West","ons_code":"S14000033","mp":"Carol Monaghan MP","signature_count":23},{"name":"Glasgow South","ons_code":"S14000034","mp":"Stewart Malcolm McDonald MP","signature_count":12}`
#
#
# The text in quotes are the **name ** of for the data and the content after the colon is the ** value ** e.g. `"mp":"Mr Paul Sweeney MP"`
#
# To access the json data we can use the link [https://petition.parliament.uk/petitions/233926.json](https://petition.parliament.uk/petitions/233926.json) (note it's the same link with `.json` added.)
#
# We'll grab that using the get function from the requests library.

# %%
response  = requests.get(' https://petition.parliament.uk/petitions/233926.json')
response.text
# Out:
# '{"links":{"self":"https://petition.parliament.uk/petitions/233926.json"},"data":{"type":"petition","id":233926,"attributes":{"action":"People found with a knife to get 10 years and using a knife 25 years in prison.","background":"People are scared of the amount of knife crime with apparently very little deterent to stop people carrying knifes.","additional_details":"","state":"open","signature_count":107575,"created_at":"2018-11-26T19:42:52.146Z","updated_at":"2019-03-26T14:56:35.126Z","rejected_at":null,"opened_at":"2018-12-03T11:13:14.938Z","closed_at":null,"moderation_threshold_reached_at":"2018-11-26T20:49:46.815Z","response_threshold_reached_at":"2019-02-28T01:21:25.389Z","government_response_at":"2019-03-14T16:47:38.458Z","debate_threshold_reached_at":"2019-03-13T13:20:55.518Z","scheduled_debate_date":"2019-03-25","debate_outcome_at":null,"creator_name":"John Perrins","rejection":null,"government_response":{"responded_on":"2019-03-14","summary":"Conviction of a knife or offensive weapon offence – threatening or possession - is now more likely to result in some form of custodial sentence, and for longer than at any point in the last ten years.","details":"The Government takes the possession of knives extremely seriously. We understand the devastating impact knife crime has on victims and their families, and are determined to put a stop to violent crimes that involve knives. \\r\\n\\r\\nParliament has provided a sentencing framework which give courts the powers they need to effectively deal with the range of offences and offenders which come before them. Where someone is actually harmed by a knife or offensive weapon, there are a range of offences that the person may be charged with, such as causing grievous bodily harm. These can result in lengthy sentences up to life imprisonment. In England and Wales in fact, all murder convictions must result in a life sentence. For offenders aged 18 and over who bring a knife or another weapon to the scene of a murder with the intention of using it, courts will consider a minimum term spent in custody of at least 25 years.\\r\\n\\r\\nIn 2015, we introduced minimum custodial sentences for repeat knife possession and offences that involve threatening with a weapon. Adults face a minimum of 6 months’ imprisonment whilst young people aged 16 or 17 face a minimum 4 month Detention and Training Order. Since the introduction of the minimum custodial term people caught carrying a knife or offensive weapon for a second time are now more likely than ever before to go to prison – in the year ending September 2018, 82% of offenders received a custodial sentence for repeat possession offences. These offences carry maximum terms of 4 years’ imprisonment.\\r\\n\\r\\nWhen sentencing, the courts consider the full circumstances of the offence and offender and must follow any relevant sentencing guidelines produced by the independent Sentencing Council. The guidelines are clear that for any offence the use of weapon will be treated as an aggravating factor meriting an increased sentence. \\r\\n\\r\\nIt is clear tackling serious violence requires a response on several fronts. This Government is taking significant action to both prevent and respond to crimes involving weapons through the Serious Violence Strategy, published on 9 April 2018. The Strategy sets out 61 commitments the Government will be taking forward to tackle violent crime. For example, the Offensive Weapons Bill, currently before Parliament includes provision for new offences related to knives, such as preventing the delivery of knives to home addresses when bought online. The Strategy also commits to strengthen police capability to act against violent crime, and to secure better partnership working to support young people and encourage them to take up positive activities rather than get involved in crime.\\r\\n\\r\\nMinistry of Justice.","created_at":"2019-03-14T16:47:38.455Z","updated_at":"2019-03-14T16:47:38.455Z"},"debate":null,"signa ...

# %% [markdown]
# All of the page is now stored as an object called `response`. We can see the content by using the .text function. (you'll need to scroll across to see it all). So we know it's working but we need to 'convert' the raw text into something with some structure.

# %%
petition_data = response.json()
petition_data
# Out:
# {'data': {'attributes': {'action': 'Revoke Article 50 and remain in the EU.',
#    'additional_details': '',
#    'background': "The government repeatedly claims exiting the EU is 'the will of the people'. We need to put a stop to this claim by proving the strength of public support now, for remaining in the EU. A People's Vote may not happen - so vote now.",
#    'closed_at': None,
#    'created_at': '2019-02-14T12:14:59.326Z',
#    'creator_name': 'Margaret Anne Georgiadou',
#    'debate': None,
#    'debate_outcome_at': None,
#    'debate_threshold_reached_at': '2019-03-20T20:33:35.184Z',
#    'government_response': None,
#    'government_response_at': None,
#    'moderation_threshold_reached_at': '2019-02-14T14:57:53.747Z',
#    'opened_at': '2019-02-20T10:25:02.393Z',
#    'rejected_at': None,
#    'rejection': None,
#    'response_threshold_reached_at': '2019-03-18T13:26:30.257Z',
#    'scheduled_debate_date': None,
#    'signature_count': 5735629,
#    'signatures_by_constituency': [{'mp': 'Tommy Sheppard MP',
#      'name': 'Edinburgh East',
#      'ons_code': 'S14000022',
#      'signature_count': 18452},
#     {'mp': 'Deidre Brock MP',
#      'name': 'Edinburgh North and Leith',
#      'ons_code': 'S14000023',
#      'signature_count': 26613},
#     {'mp': 'Ian Murray MP',
#      'name': 'Edinburgh South',
#      'ons_code': 'S14000024',
#      'signature_count': 19558},
#     {'mp': 'Joanna Cherry QC MP',
#      'name': 'Edinburgh South West',
#      'ons_code': 'S14000025',
#      'signature_count': 16855},
#     {'mp': 'Christine Jardine MP',
#      'name': 'Edinburgh West',
#      'ons_code': 'S14000026',
#      'signature_count': 14344},
#     {'mp': 'David Duguid MP',
#      'name': 'Banff and Buchan',
#      'ons_code': 'S14000007',
#      'signature_count': 3792},
#     {'mp': 'John McNally MP',
#      'name': 'Falkirk',
#      'ons_code': 'S14000028',
#      'signature_count': 8544},
#     {'mp': 'Alison Thewliss MP',
#      'name': 'Glasgow Central',
#      'ons_code': 'S14000029',
#      'signature_count': 13885},
#     {'mp': 'David Linden MP',
#      'name': 'Glasgow East',
#      'ons_code': 'S14000030',
#      'signature_count': 4868},
#     {'mp': 'Patrick Grady MP',
#      'name': 'Glasgow North',
#      'ons_code': 'S14000031',
#      'signature_count': 14342},
#     {'mp': 'Mr Paul Sweeney MP',
#      'name': 'Glasgow North East',
#      'ons_code': 'S14000032',
#      'signature_count': 5779},
#     {'mp': 'Carol Monaghan MP',
#      'name': 'Glasgow North West',
#      'ons_code': 'S14000033',
#      'signature_count': 10367},
#     {'mp': 'Stewart Malcolm McDonald MP',
#      'name': 'Glasgow South',
#      'ons_code': 'S14000034',
#      'signature_count': 12984},
#     {'mp': 'Chris Stephens MP',
#      'name': 'Glasgow South West',
#      'ons_code': 'S14000035',
#      'signature_count': 5799},
#     {'mp': 'Peter Grant MP',
#      'name': 'Glenrothes',
#      'ons_code': 'S14000036',
#      'signature_count': 4413},
#     {'mp': 'Colin Clark MP',
#      'name': 'Gordon',
#      'ons_code': 'S14000037',
#      'signature_count': 8781},
#     {'mp': 'Kirsty Blackman MP',
#      'name': 'Aberdeen North',
#      'ons_code': 'S14000001',
#      'signature_count': 8716},
#     {'mp': 'Ronnie Cowan MP',
#      'name': 'Inverclyde',
#      'ons_code': 'S14000038',
#      'signature_count': 5872},
#     {'mp': 'Drew Hendry MP',
#      'name': 'Inverness, Nairn, Badenoch and Strathspey',
#      'ons_code': 'S14000039',
#      'signature_count': 9868},
#     {'mp': 'Alan Brown MP',
#      'name': 'Kilmarnock and Loudoun',
#      'ons_code': 'S14000040',
#      'signature_count': 6218},
#     {'mp': 'Lesley Laird MP',
#      'name': 'Kirkcaldy and Cowdenbeath',
#      'ons_code': 'S14000041',
#      'signature_count': 6980},
#     {'mp': 'Angela Crawley MP',
#      'name': 'Lanark and Hamilton East',
#      'ons_code': 'S14000042',
#      'signature_count': 7467},
#     {'mp': 'Martyn Day MP',
#      'name': 'Linlithgow and East Falkirk',
#      'ons_code': 'S14000043',
#      'signature_count': 9648},
#     {'mp': 'Hannah Bardell MP',
#      'name': 'Livingston',
#      'ons_code': 'S14000044',
#      'signature_count': 9111},
#     {'mp': 'Danielle Rowley MP',
#      'name': 'Midlothian',
#      'ons_code': 'S14000045',
#      'signature_count': 9003},
#     {'mp': 'Ross Thomson MP',
#      'name': 'Aberdeen South',
#      'ons_code': 'S14000002',
#      'signature_count': 10429},
#     {'mp': 'Douglas Ross MP',
#      'name': 'Moray',
#      'ons_code': 'S14000046',
#      'signature_count': 6011},
#     {'mp': 'Marion Fellows MP',
#      'name': 'Motherwell and Wishaw',
#      'ons_code': 'S14000047',
#      'signature_count': 5476},
#     {'mp': 'Angus Brendan MacNeil MP',
#      'name': 'Na h-Eileanan an Iar',
#      'ons_code': 'S14000027',
#      'signature_count': 2266},
#     {'mp': 'Patricia Gibson MP',
#      'name': 'North Ayrshire and Arran',
#      'ons_code': 'S14000048',
#      'signature_count': 6472},
#     {'mp': 'Stephen Gethins MP',
#      'name': 'North East Fife',
#      'ons_code': 'S14000049',
#      'signature_count': 10017},
#     {'mp': 'John Lamont MP',
#      'name': 'Berwickshire, Roxburgh and Selkirk',
#      'ons_code': 'S14000008',
#      'signature_count': 7820},
#     {'mp': 'Luke Graham MP',
#      'name': 'Ochil and South Perthshire',
#      'ons_code': 'S14000050',
#      'signature_count': 9492},
#     {'mp': 'Rt Hon Alistair Carmichael MP',
#      'name': 'Orkney and Shetland',
#      'ons_code': 'S14000051',
#      'signature_count': 4307},
#     {'mp': 'Gavin Newlands MP',
#      'name': 'Paisley and Renfrewshire North',
#      'ons_code': 'S14000052',
#      'signature_count': 8281},
#     {'mp': 'Mhairi Black MP',
#      'name': 'Paisley and Renfrewshire South',
#      'ons_code': 'S14000053',
#      'signature_count': 7364},
#     {'mp': 'Pete Wishart MP',
#      'name': 'Perth and North Perthshire',
#      'ons_code': 'S14000054',
#      'signature_count': 9227},
#     {'mp': 'Rt Hon Ian Blackford MP',
#      'name': 'Ross, Skye and Lochaber',
#      'ons_code': 'S14000055',
#      'signature_count': 8535},
#     {'mp': 'Ged Killen MP',
#      'name': 'Rutherglen and Hamilton West',
#      'ons_code': 'S14000056',
#      'signature_count': 8340},
#     {'mp': 'Stephen Kerr MP',
#      'name': 'Stirling',
#      'ons_code': 'S14000057',
#      'signature_count': 11918},
#     {'mp': 'Andrew Bowie MP',
#      'name': 'West Aberdeenshire and Kincardine',
#      'ons_code': 'S14000058',
#      'signature_count': 10200},
#     {'mp': 'Martin Docherty-Hughes MP',
#      'name': 'West Dunbartonshire',
#      'ons_code': 'S14000059',
#      'signature_count': 6401},
#     {'mp': 'Stephen Kinnock MP',
#      'name': 'Aberavon',
#      'ons_code': 'W07000049',
#      'signature_count': 2895},
#     {'mp': 'Guto Bebb MP',
#      'name': 'Aberconwy',
#      'ons_code': 'W07000058',
#      'signature_count': 4455},
#     {'mp': 'Leo Docherty MP',
#      'name': 'Aldershot',
#      'ons_code': 'E14000530',
#      'signature_count': 7109},
#     {'mp': 'Wendy Morton MP',
#      'name': 'Aldridge-Brownhills',
#      'ons_code': 'E14000531',
#      'signature_count': 2831},
#     {'mp': 'Sir Graham Brady MP',
#      'name': 'Altrincham and Sale West',
#      'ons_code': 'E14000532',
#      'signature_count': 12628},
#     {'mp': 'Rt Hon Mark Tami MP',
#      'name': 'Alyn and Deeside',
#      'ons_code': 'W07000043',
#      'signature_count': 5058},
#     {'mp': 'Nigel Mills MP',
#      'name': 'Amber Valley',
#      'ons_code': 'E14000533',
#      'signature_count': 3862},
#     {'mp': 'Hywel Williams MP',
#      'name': 'Arfon',
#      'ons_code': 'W07000057',
#      'signature_count': 6735},
#     {'mp': 'Rt Hon Nick Herbert MP',
#      'name': 'Arundel and South Downs',
#      'ons_code': 'E14000534',
#      'signature_count': 12009},
#     {'mp': 'Gloria De Piero MP',
#      'name': 'Ashfield',
#      'ons_code': 'E14000535',
#      'signature_count': 3217},
#     {'mp': 'Rt Hon Damian Green MP',
#      'name': 'Ashford',
#      'ons_code': 'E14000536',
#      'signature_count': 8529},
#     {'mp': 'Angela Rayner MP',
#      'name': 'Ashton-under-Lyne',
#      'ons_code': 'E14000537',
#      'signature_count': 3754},
#     {'mp': 'Rt Hon David Lidington MP',
#      'name': 'Aylesbury',
#      'ons_code': 'E14000538',
#      'signature_count': 9477},
#     {'mp': 'Victoria Prentis MP',
#      'name': 'Banbury',
#      'ons_code': 'E14000539',
#      'signature_count': 11659},
#     {'mp': 'Rt Hon Dame Margaret Hodge MP',
#      'name': 'Barking',
#      'ons_code': 'E14000540',
#      'signature_count': 5251},
#     {'mp': 'Dan Jarvis MP',
#      'name': 'Barnsley Central',
#      'ons_code': 'E14000541',
#      'signature_count': 2938},
#     {'mp': 'Stephanie Peacock MP',
#      'name': 'Barnsley East',
#      'ons_code': 'E14000542',
#      'signature_count': 2307},
#     {'mp': 'John Woodcock MP',
#      'name': 'Barrow and Furness',
#      'ons_code': 'E14000543',
#      'signature_count': 4452},
#     {'mp': 'Mr John Baron MP',
#      'name': 'Basildon and Billericay',
#      'ons_code': 'E14000544',
#      'signature_count': 4860},
#     {'mp': 'Rt Hon Maria Miller MP',
#      'name': 'Basingstoke',
#      'ons_code': 'E14000545',
#      'signature_count': 9147},
#     {'mp': 'John Mann MP',
#      'name': 'Bassetlaw',
#      'ons_code': 'E14000546',
#      'signature_count': 3837},
#     {'mp': 'Wera Hobhouse MP',
#      'name': 'Bath',
#      'ons_code': 'E14000547',
#      'signature_count': 17440},
#     {'mp': 'Tracy Brabin MP',
#      'name': 'Batley and Spen',
#      'ons_code': 'E14000548',
#      'signature_count': 3917},
#     {'mp': 'Marsha De Cordova MP',
#      'name': 'Battersea',
#      'ons_code': 'E14000549',
#      'signature_count': 23499},
#     {'mp': 'Rt Hon Dominic Grieve QC MP',
#      'name': 'Beaconsfield',
#      'ons_code': 'E14000550',
#      'signature_count': 11054},
#     {'mp': 'Bob Stewart MP',
#      'name': 'Beckenham',
#      'ons_code': 'E14000551',
#      'signature_count': 11492},
#     {'mp': 'Mohammad Yasin MP',
#      'name': 'Bedford',
#      'ons_code': 'E14000552',
#      'signature_count': 7362},
#     {'mp': 'Gavin Robinson MP',
#      'name': 'Belfast East',
#      'ons_code': 'N06000001',
#      'signature_count': 7155},
#     {'mp': 'Rt Hon Nigel Dodds MP',
#      'name': 'Belfast North',
#      'ons_code': 'N06000002',
#      'signature_count': 6493},
#     {'mp': 'Emma Little Pengelly MP',
#      'name': 'Belfast South',
#      'ons_code': 'N06000003',
#      'signature_count': 15089},
#     {'mp': 'Paul Maskey MP',
#      'name': 'Belfast West',
#      'ons_code': 'N06000004',
#      'signature_count': 5439},
#     {'mp': 'Neil Coyle MP',
#      'name': 'Bermondsey and Old Southwark',
#      'ons_code': 'E14000553',
#      'signature_count': 24112},
#     {'mp': 'Anne-Marie Trevelyan MP',
#      'name': 'Berwick-upon-Tweed',
#      'ons_code': 'E14000554',
#      'signature_count': 5030},
#     {'mp': 'Rushanara Ali MP',
#      'name': 'Bethnal Green and Bow',
#      'ons_code': 'E14000555',
#      'signature_count': 23437},
#     {'mp': 'Graham Stuart MP',
#      'name': 'Beverley and Holderness',
#      'ons_code': 'E14000556',
#      'signature_count': 5777},
#     {'mp': 'Huw Merriman MP',
#      'name': 'Bexhill and Battle',
#      'ons_code': 'E14000557',
#      'signature_count': 8540},
#     {'mp': 'Rt Hon Sir David Evennett MP',
#      'name': 'Bexleyheath and Crayford',
#      'ons_code': 'E14000558',
#      'signature_count': 4981},
#     {'mp': 'Rt Hon Frank Field MP',
#      'name': 'Birkenhead',
#      'ons_code': 'E14000559',
#      'signature_count': 5645},
#     {'mp': 'Preet Kaur Gill MP',
#      'name': 'Birmingham, Edgbaston',
#      'ons_code': 'E14000560',
#      'signature_count': 8126},
#     {'mp': 'Jack Dromey MP',
#      'name': 'Birmingham, Erdington',
#      'ons_code': 'E14000561',
#      'signature_count': 3356},
#     {'mp': 'Mr Roger Godsiff MP',
#      'name': 'Birmingham, Hall Green',
#      'ons_code': 'E14000562',
#      'signature_count': 8648},
#     {'mp': 'Rt Hon Liam Byrne MP',
#      'name': 'Birmingham, Hodge Hill',
#      'ons_code': 'E14000563',
#      'signature_count': 2438},
#     {'mp': 'Shabana Mahmood MP',
#      'name': 'Birmingham, Ladywood',
#      'ons_code': 'E14000564',
#      'signature_count': 6758},
#     {'mp': 'Richard Burden MP',
#      'name': 'Birmingham, Northfield',
#      'ons_code': 'E14000565',
#      'signature_count': 4931},
#     {'mp': 'Mr Khalid Mahmood MP',
#      'name': 'Birmingham, Perry Barr',
#      'ons_code': 'E14000566',
#      'signature_count': 3119},
#     {'mp': 'Steve McCabe MP',
#      'name': 'Birmingham, Selly Oak',
#      'ons_code': 'E14000567',
#      'signature_count': 9666},
#     {'mp': 'Jess Phillips MP',
#      'name': 'Birmingham, Yardley',
#      'ons_code': 'E14000568',
#      'signature_count': 3601},
#     {'mp': 'Helen Goodman MP',
#      'name': 'Bishop Auckland',
#      'ons_code': 'E14000569',
#      'signature_count': 3717},
#     {'mp': 'Kate Hollern MP',
#      'name': 'Blackburn',
#      'ons_code': 'E14000570',
#      'signature_count': 3005},
#     {'mp': 'Graham Stringer MP',
#      'name': 'Blackley and Broughton',
#      'ons_code': 'E14000571',
#      'signature_count': 5227},
#     {'mp': 'Paul Maynard MP',
#      'name': 'Blackpool North and Cleveleys',
#      'ons_code': 'E14000572',
#      'signature_count': 3031},
#     {'mp': 'Gordon Marsden MP',
#      'name': 'Blackpool South',
#      'ons_code': 'E14000573',
#      'signature_count': 2479},
#     {'mp': 'Nick Smith MP',
#      'name': 'Blaenau Gwent',
#      'ons_code': 'W07000072',
#      'signature_count': 2109},
#     {'mp': 'Liz Twist MP',
#      'name': 'Blaydon',
#      'ons_code': 'E14000574',
#      'signature_count': 5622},
#     {'mp': 'Mr Ronnie Campbell MP',
#      'name': 'Blyth Valley',
#      'ons_code': 'E14000575',
#      'signature_count': 3765},
#     {'mp': 'Rt Hon Nick Gibb MP',
#      'name': 'Bognor Regis and Littlehampton',
#      'ons_code': 'E14000576',
#      'signature_count': 5767},
#     {'mp': 'Mr Dennis Skinner MP',
#      'name': 'Bolsover',
#      'ons_code': 'E14000577',
#      'signature_count': 3293},
#     {'mp': 'Sir David Crausby MP',
#      'name': 'Bolton North East',
#      'ons_code': 'E14000578',
#      'signature_count': 3994},
#     {'mp': 'Yasmin Qureshi MP',
#      'name': 'Bolton South East',
#      'ons_code': 'E14000579',
#      'signature_count': 2905},
#     {'mp': 'Chris Green MP',
#      'name': 'Bolton West',
#      'ons_code': 'E14000580',
#      'signature_count': 5355},
#     {'mp': 'Peter Dowd MP',
#      'name': 'Bootle',
#      'ons_code': 'E14000581',
#      'signature_count': 6568},
#     {'mp': 'Matt Warman MP',
#      'name': 'Boston and Skegness',
#      'ons_code': 'E14000582',
#      'signature_count': 2567},
#     {'mp': 'David Tredinnick MP',
#      'name': 'Bosworth',
#      'ons_code': 'E14000583',
#      'signature_count': 6029},
#     {'mp': 'Rt Hon Tobias Ellwood MP',
#      'name': 'Bournemouth East',
#      'ons_code': 'E14000584',
#      'signature_count': 9654},
#     {'mp': 'Conor Burns MP',
#      'name': 'Bournemouth West',
#      'ons_code': 'E14000585',
#      'signature_count': 8116},
#     {'mp': 'Dr Phillip Lee MP',
#      'name': 'Bracknell',
#      'ons_code': 'E14000586',
#      'signature_count': 9335},
#     {'mp': 'Imran Hussain MP',
#      'name': 'Bradford East',
#      'ons_code': 'E14000587',
#      'signature_count': 3175},
#     {'mp': 'Judith Cummins MP',
#      'name': 'Bradford South',
#      'ons_code': 'E14000588',
#      'signature_count': 2806},
#     {'mp': 'Naz Shah MP',
#      'name': 'Bradford West',
#      'ons_code': 'E14000589',
#      'signature_count': 3376},
#     {'mp': 'James Cleverly MP',
#      'name': 'Braintree',
#      'ons_code': 'E14000590',
#      'signature_count': 5776},
#     {'mp': 'Chris Davies MP',
#      'name': 'Brecon and Radnorshire',
#      'ons_code': 'W07000068',
#      'signature_count': 5832},
#     {'mp': 'Dawn Butler MP',
#      'name': 'Brent Central',
#      'ons_code': 'E14000591',
#      'signature_count': 12486},
#     {'mp': 'Barry Gardiner MP',
#      'name': 'Brent North',
#      'ons_code': 'E14000592',
#      'signature_count': 7890},
#     {'mp': 'Ruth Cadbury MP',
#      'name': 'Brentford and Isleworth',
#      'ons_code': 'E14000593',
#      'signature_count': 18736},
#     {'mp': 'Alex Burghart MP',
#      'name': 'Brentwood and Ongar',
#      'ons_code': 'E14000594',
#      'signature_count': 6820},
#     {'mp': 'Mrs Madeleine Moon MP',
#      'name': 'Bridgend',
#      'ons_code': 'W07000073',
#      'signature_count': 5153},
#     {'mp': 'Mr Ian Liddell-Grainger MP',
#      'name': 'Bridgwater and West Somerset',
#      'ons_code': 'E14000595',
#      'signature_count': 6396},
#     {'mp': 'Andrew Percy MP',
#      'name': 'Brigg and Goole',
#      'ons_code': 'E14000596',
#      'signature_count': 3220},
#     {'mp': 'Lloyd Russell-Moyle MP',
#      'name': 'Brighton, Kemptown',
#      'ons_code': 'E14000597',
#      'signature_count': 14312},
#     {'mp': 'Caroline Lucas MP',
#      'name': 'Brighton, Pavilion',
#      'ons_code': 'E14000598',
#      'signature_count': 27768},
#     {'mp': 'Kerry McCarthy MP',
#      'name': 'Bristol East',
#      'ons_code': 'E14000599',
#      'signature_count': 12084},
#     {'mp': 'Darren Jones MP',
#      'name': 'Bristol North West',
#      'ons_code': 'E14000600',
#      'signature_count': 14620},
#     {'mp': 'Karin Smyth MP',
#      'name': 'Bristol South',
#      'ons_code': 'E14000601',
#      'signature_count': 15272},
#     {'mp': 'Thangam Debbonaire MP',
#      'name': 'Bristol West',
#      'ons_code': 'E14000602',
#      'signature_count': 35450},
#     {'mp': 'Rt Hon Keith Simpson MP',
#      'name': 'Broadland',
#      'ons_code': 'E14000603',
#      'signature_count': 7328},
#     {'mp': 'Robert Neill MP',
#      'name': 'Bromley and Chislehurst',
#      'ons_code': 'E14000604',
#      'signature_count': 10459},
#     {'mp': 'Rt Hon Sajid Javid MP',
#      'name': 'Bromsgrove',
#      'ons_code': 'E14000605',
#      'signature_count': 7267},
#     {'mp': 'Mr Charles Walker MP',
#      'name': 'Broxbourne',
#      'ons_code': 'E14000606',
#      'signature_count': 5216},
#     {'mp': 'Rt Hon Anna Soubry MP',
#      'name': 'Broxtowe',
#      'ons_code': 'E14000607',
#      'signature_count': 9279},
#     {'mp': 'Rt Hon John Bercow MP',
#      'name': 'Buckingham',
#      'ons_code': 'E14000608',
#      'signature_count': 11889},
#     {'mp': 'Julie Cooper MP',
#      'name': 'Burnley',
#      'ons_code': 'E14000609',
#      'signature_count': 2592},
#     {'mp': 'Andrew Griffiths MP',
#      'name': 'Burton',
#      'ons_code': 'E14000610',
#      'signature_count': 4653},
#     {'mp': 'James Frith MP',
#      'name': 'Bury North',
#      'ons_code': 'E14000611',
#      'signature_count': 5594},
#     {'mp': 'Mr Ivan Lewis MP',
#      'name': 'Bury South',
#      'ons_code': 'E14000612',
#      'signature_count': 7038},
#     {'mp': 'Jo Churchill MP',
#      'name': 'Bury St Edmunds',
#      'ons_code': 'E14000613',
#      'signature_count': 9171},
#     {'mp': 'Wayne David MP',
#      'name': 'Caerphilly',
#      'ons_code': 'W07000076',
#      'signature_count': 4612},
#     {'mp': 'Craig Whittaker MP',
#      'name': 'Calder Valley',
#      'ons_code': 'E14000614',
#      'signature_count': 9729},
#     {'mp': 'Rt Hon Harriet Harman QC MP',
#      'name': 'Camberwell and Peckham',
#      'ons_code': 'E14000615',
#      'signature_count': 21511},
#     {'mp': 'George Eustice MP',
#      'name': 'Camborne and Redruth',
#      'ons_code': 'E14000616',
#      'signature_count': 6683},
#     {'mp': 'Daniel Zeichner MP',
#      'name': 'Cambridge',
#      'ons_code': 'E14000617',
#      'signature_count': 26693},
#     {'mp': 'Amanda Milling MP',
#      'name': 'Cannock Chase',
#      'ons_code': 'E14000618',
#      'signature_count': 3012},
#     {'mp': 'Rosie Duffield MP',
#      'name': 'Canterbury',
#      'ons_code': 'E14000619',
#      'signature_count': 13931},
#     {'mp': 'Jo Stevens MP',
#      'name': 'Cardiff Central',
#      'ons_code': 'W07000050',
#      'signature_count': 11285},
#     {'mp': 'Anna McMorrin MP',
#      'name': 'Cardiff North',
#      'ons_code': 'W07000051',
#      'signature_count': 11217},
#     {'mp': 'Stephen Doughty MP',
#      'name': 'Cardiff South and Penarth',
#      'ons_code': 'W07000080',
#      'signature_count': 10972},
#     {'mp': 'Kevin Brennan MP',
#      'name': 'Cardiff West',
#      'ons_code': 'W07000079',
#      'signature_count': 11040},
#     {'mp': 'John Stevenson MP',
#      'name': 'Carlisle',
#      'ons_code': 'E14000620',
#      'signature_count': 4110},
#     {'mp': 'Jonathan Edwards MP',
#      'name': 'Carmarthen East and Dinefwr',
#      'ons_code': 'W07000067',
#      'signature_count': 4887},
#     {'mp': 'Simon Hart MP',
#      'name': 'Carmarthen West and South Pembrokeshire',
#      'ons_code': 'W07000066',
#      'signature_count': 4796},
#     {'mp': 'Rt Hon Tom Brake MP',
#      'name': 'Carshalton and Wallington',
#      'ons_code': 'E14000621',
#      'signature_count': 8273},
#     {'mp': 'Rebecca Harris MP',
#      'name': 'Castle Point',
#      'ons_code': 'E14000622',
#      'signature_count': 3011},
#     {'mp': 'Rt Hon Mel Stride MP',
#      'name': 'Central Devon',
#      'ons_code': 'E14000623',
#      'signature_count': 11144},
#     {'mp': 'Dr Dan Poulter MP',
#      'name': 'Central Suffolk and North Ipswich',
#      'ons_code': 'E14000624',
#      'signature_count': 7987},
#     {'mp': 'Ben Lake MP',
#      'name': 'Ceredigion',
#      'ons_code': 'W07000064',
#      'signature_count': 7597},
#     {'mp': 'Edward Argar MP',
#      'name': 'Charnwood',
#      'ons_code': 'E14000625',
#      'signature_count': 6132},
#     {'mp': 'Tracey Crouch MP',
#      'name': 'Chatham and Aylesford',
#      'ons_code': 'E14000626',
#      'signature_count': 4385},
#     {'mp': 'Mary Robinson MP',
#      'name': 'Cheadle',
#      'ons_code': 'E14000627',
#      'signature_count': 10445},
#     {'mp': 'Vicky Ford MP',
#      'name': 'Chelmsford',
#      'ons_code': 'E14000628',
#      'signature_count': 9333},
#     {'mp': 'Rt Hon Greg Hands MP',
#      'name': 'Chelsea and Fulham',
#      'ons_code': 'E14000629',
#      'signature_count': 19664},
#     {'mp': 'Alex Chalk MP',
#      'name': 'Cheltenham',
#      'ons_code': 'E14000630',
#      'signature_count': 13498},
#     {'mp': 'Rt Hon Dame Cheryl Gillan MP',
#      'name': 'Chesham and Amersham',
#      'ons_code': 'E14000631',
#      'signature_count': 12689},
#     {'mp': 'Toby Perkins MP',
#      'name': 'Chesterfield',
#      'ons_code': 'E14000632',
#      'signature_count': 4982},
#     {'mp': 'Gillian Keegan MP',
#      'name': 'Chichester',
#      'ons_code': 'E14000633',
#      'signature_count': 11679},
#     {'mp': 'Rt Hon Iain Duncan Smith MP',
#      'name': 'Chingford and Woodford Green',
#      'ons_code': 'E14000634',
#      'signature_count': 9033},
#     {'mp': 'Michelle Donelan MP',
#      'name': 'Chippenham',
#      'ons_code': 'E14000635',
#      'signature_count': 10461},
#     {'mp': 'Rt Hon Theresa Villiers MP',
#      'name': 'Chipping Barnet',
#      'ons_code': 'E14000636',
#      'signature_count': 15644},
#     {'mp': 'Rt Hon Sir Lindsay Hoyle MP',
#      'name': 'Chorley',
#      'ons_code': 'E14000637',
#      'signature_count': 6263},
#     {'mp': 'Sir Christopher Chope MP',
#      'name': 'Christchurch',
#      'ons_code': 'E14000638',
#      'signature_count': 6205},
#     {'mp': 'Rt Hon Mark Field MP',
#      'name': 'Cities of London and Westminster',
#      'ons_code': 'E14000639',
#      'signature_count': 23653},
#     {'mp': 'Christian Matheson MP',
#      'name': 'City of Chester',
#      'ons_code': 'E14000640',
#      'signature_count': 10989},
#     {'mp': 'Dr Roberta Blackman-Woods MP',
#      'name': 'City of Durham',
#      'ons_code': 'E14000641',
#      'signature_count': 8151},
#     {'mp': 'Giles Watling MP',
#      'name': 'Clacton',
#      'ons_code': 'E14000642',
#      'signature_count': 2587},
#     {'mp': 'Martin Vickers MP',
#      'name': 'Cleethorpes',
#      'ons_code': 'E14000643',
#      'signature_count': 3078},
#     {'mp': 'Susan Elan Jones MP',
#      'name': 'Clwyd South',
#      'ons_code': 'W07000062',
#      'signature_count': 3927},
#     {'mp': 'Rt Hon David Jones MP',
#      'name': 'Clwyd West',
#      'ons_code': 'W07000059',
#      'signature_count': 5182},
#     {'mp': 'Will Quince MP',
#      'name': 'Colchester',
#      'ons_code': 'E14000644',
#      'signature_count': 9452},
#     {'mp': 'Thelma Walker MP',
#      'name': 'Colne Valley',
#      'ons_code': 'E14000645',
#      'signature_count': 8556},
#     {'mp': 'Fiona Bruce MP',
#      'name': 'Congleton',
#      'ons_code': 'E14000646',
#      'signature_count': 7646},
#     {'mp': 'Trudy Harrison MP',
#      'name': 'Copeland',
#      'ons_code': 'E14000647',
#      'signature_count': 4093},
#     {'mp': 'Tom Pursglove MP',
#      'name': 'Corby',
#      'ons_code': 'E14000648',
#      'signature_count': 6907},
#     {'mp': 'Colleen Fletcher MP',
#      'name': 'Coventry North East',
#      'ons_code': 'E14000649',
#      'signature_count': 4733},
#     {'mp': 'Mr Geoffrey Robinson MP',
#      'name': 'Coventry North West',
#      'ons_code': 'E14000650',
#      'signature_count': 6205},
#     {'mp': 'Mr Jim Cunningham MP',
#      'name': 'Coventry South',
#      'ons_code': 'E14000651',
#      'signature_count': 7681},
#     {'mp': 'Henry Smith MP',
#      'name': 'Crawley',
#      'ons_code': 'E14000652',
#      'signature_count': 6523},
#     {'mp': 'Laura Smith MP',
#      'name': 'Crewe and Nantwich',
#      'ons_code': 'E14000653',
#      'signature_count': 6590},
#     {'mp': 'Sarah Jones MP',
#      'name': 'Croydon Central',
#      'ons_code': 'E14000654',
#      'signature_count': 9414},
#     {'mp': 'Mr Steve Reed MP',
#      'name': 'Croydon North',
#      'ons_code': 'E14000655',
#      'signature_count': 11674},
#     {'mp': 'Chris Philp MP',
#      'name': 'Croydon South',
#      'ons_code': 'E14000656',
#      'signature_count': 11723},
#     {'mp': 'Rt Hon Ann Clwyd MP',
#      'name': 'Cynon Valley',
#      'ons_code': 'W07000070',
#      'signature_count': 2592},
#     {'mp': 'Jon Cruddas MP',
#      'name': 'Dagenham and Rainham',
#      'ons_code': 'E14000657',
#      'signature_count': 3558},
#     {'mp': 'Jenny Chapman MP',
#      'name': 'Darlington',
#      'ons_code': 'E14000658',
#      'signature_count': 4735},
#     {'mp': 'Gareth Johnson MP',
#      'name': 'Dartford',
#      'ons_code': 'E14000659',
#      'signature_count': 5880},
#     {'mp': 'Chris Heaton-Harris MP',
#      'name': 'Daventry',
#      'ons_code': 'E14000660',
#      'signature_count': 7734},
#     {'mp': 'Rt Hon David Hanson MP',
#      'name': 'Delyn',
#      'ons_code': 'W07000042',
#      'signature_count': 4437},
#     {'mp': 'Andrew Gwynne MP',
#      'name': 'Denton and Reddish',
#      'ons_code': 'E14000661',
#      'signature_count': 4420},
#     {'mp': 'Chris Williamson MP',
#      'name': 'Derby North',
#      'ons_code': 'E14000662',
#      'signature_count': 7095},
#     {'mp': 'Rt Hon Margaret Beckett MP',
#      'name': 'Derby South',
#      'ons_code': 'E14000663',
#      'signature_count': 4468},
#     {'mp': 'Rt Hon Sir Patrick McLoughlin MP',
#      'name': 'Derbyshire Dales',
#      'ons_code': 'E14000664',
#      'signature_count': 8661},
#     {'mp': 'Rt Hon Claire Perry MP',
#      'name': 'Devizes',
#      'ons_code': 'E14000665',
#      'signature_count': 8008},
#     {'mp': 'Paula Sherriff MP',
#      'name': 'Dewsbury',
#      'ons_code': 'E14000666',
#      'signature_count': 5068},
#     {'mp': 'Rt Hon Caroline Flint MP',
#      'name': 'Don Valley',
#      'ons_code': 'E14000667',
#      'signature_count': 3200},
#     {'mp': 'Rt Hon Dame Rosie Winterton MP',
#      'name': 'Doncaster Central',
#      'ons_code': 'E14000668',
#      'signature_count': 3713},
#     {'mp': 'Rt Hon Edward Miliband MP',
#      'name': 'Doncaster North',
#      'ons_code': 'E14000669',
#      'signature_count': 2548},
#     {'mp': 'Charlie Elphicke MP',
#      'name': 'Dover',
#      'ons_code': 'E14000670',
#      'signature_count': 6109},
#     {'mp': 'Ian Austin MP',
#      'name': 'Dudley North',
#      'ons_code': 'E14000671',
#      'signature_count': 1999},
#     {'mp': 'Mike Wood MP',
#      'name': 'Dudley South',
#      'ons_code': 'E14000672',
#      'signature_count': 2383},
#     {'mp': 'Helen Hayes MP',
#      'name': 'Dulwich and West Norwood',
#      'ons_code': 'E14000673',
#      'signature_count': 25373},
#     {'mp': 'Rt Hon Liz Saville Roberts MP',
#      'name': 'Dwyfor Meirionnydd',
#      'ons_code': 'W07000061',
#      'signature_count': 4592},
#     {'mp': 'Dr Rupa Huq MP',
#      'name': 'Ealing Central and Acton',
#      'ons_code': 'E14000674',
#      'signature_count': 22587},
#     {'mp': 'Stephen Pound MP',
#      'name': 'Ealing North',
#      'ons_code': 'E14000675',
#      'signature_count': 9748},
#     {'mp': 'Mr Virendra Sharma MP',
#      'name': 'Ealing, Southall',
#      'ons_code': 'E14000676',
#      'signature_count': 8123},
#     {'mp': 'Grahame Morris MP',
#      'name': 'Easington',
#      'ons_code': 'E14000677',
#      'signature_count': 2109},
#     {'mp': 'Rt Hon Sammy Wilson MP',
#      'name': 'East Antrim',
#      'ons_code': 'N06000005',
#      'signature_count': 4935},
#     {'mp': 'Rt Hon Sir Hugo Swire MP',
#      'name': 'East Devon',
#      'ons_code': 'E14000678',
#      'signature_count': 10578},
#     {'mp': 'Rt Hon Stephen Timms MP',
#      'name': 'East Ham',
#      'ons_code': 'E14000679',
#      'signature_count': 7235},
#     {'mp': 'Rt Hon Damian Hinds MP',
#      'name': 'East Hampshire',
#      'ons_code': 'E14000680',
#      'signature_count': 11218},
#     {'mp': 'Mr Gregory Campbell MP',
#      'name': 'East Londonderry',
#      'ons_code': 'N06000006',
#      'signature_count': 4803},
#     {'mp': 'Mr Sam Gyimah MP',
#      'name': 'East Surrey',
#      'ons_code': 'E14000681',
#      'signature_count': 10601},
#     {'mp': 'Tim Loughton MP',
#      'name': 'East Worthing and Shoreham',
#      'ons_code': 'E14000682',
#      'signature_count': 10258},
#     {'mp': 'Rt Hon Sir Greg Knight MP',
#      'name': 'East Yorkshire',
#      'ons_code': 'E14000683',
#      'signature_count': 5007},
#     {'mp': 'Stephen Lloyd MP',
#      'name': 'Eastbourne',
#      'ons_code': 'E14000684',
#      'signature_count': 8649},
#     {'mp': 'Mims Davies MP',
#      'name': 'Eastleigh',
#      'ons_code': 'E14000685',
#      'signature_count': 8571},
#     {'mp': 'Antoinette Sandbach MP',
#      'name': 'Eddisbury',
#      'ons_code': 'E14000686',
#      'signature_count': 7066},
#     {'mp': 'Kate Osamor MP',
#      'name': 'Edmonton',
#      'ons_code': 'E14000687',
#      'signature_count': 4889},
#     {'mp': 'Justin Madders MP',
#      'name': 'Ellesmere Port and Neston',
#      'ons_code': 'E14000688',
#      'signature_count': 5796},
#     {'mp': 'Alec Shelbrooke MP',
#      'name': 'Elmet and Rothwell',
#      'ons_code': 'E14000689',
#      'signature_count': 7435},
#     {'mp': 'Clive Efford MP',
#      'name': 'Eltham',
#      'ons_code': 'E14000690',
#      'signature_count': 9604},
#     {'mp': 'Rt Hon Joan Ryan MP',
#      'name': 'Enfield North',
#      'ons_code': 'E14000691',
#      'signature_count': 7102},
#     {'mp': 'Bambos Charalambous MP',
#      'name': 'Enfield, Southgate',
#      'ons_code': 'E14000692',
#      'signature_count': 13035},
#     {'mp': 'Rt Hon Dame Eleanor Laing MP',
#      'name': 'Epping Forest',
#      'ons_code': 'E14000693',
#      'signature_count': 7396},
#     {'mp': 'Rt Hon Chris Grayling MP',
#      'name': 'Epsom and Ewell',
#      'ons_code': 'E14000694',
#      'signature_count': 12558},
#     {'mp': 'Maggie Throup MP',
#      'name': 'Erewash',
#      'ons_code': 'E14000695',
#      'signature_count': 5076},
#     {'mp': 'Teresa Pearce MP',
#      'name': 'Erith and Thamesmead',
#      'ons_code': 'E14000696',
#      'signature_count': 5280},
#     {'mp': 'Rt Hon Dominic Raab MP',
#      'name': 'Esher and Walton',
#      'ons_code': 'E14000697',
#      'signature_count': 16838},
#     {'mp': 'Rt Hon Ben Bradshaw MP',
#      'name': 'Exeter',
#      'ons_code': 'E14000698',
#      'signature_count': 13776},
#     {'mp': 'Suella Braverman MP',
#      'name': 'Fareham',
#      'ons_code': 'E14000699',
#      'signature_count': 7785},
#     {'mp': 'Helen Whately MP',
#      'name': 'Faversham and Mid Kent',
#      'ons_code': 'E14000700',
#      'signature_count': 7557},
#     {'mp': 'Seema Malhotra MP',
#      'name': 'Feltham and Heston',
#      'ons_code': 'E14000701',
#      'signature_count': 6069},
#     {'mp': 'Michelle Gildernew MP',
#      'name': 'Fermanagh and South Tyrone',
#      'ons_code': 'N06000007',
#      'signature_count': 5874},
#     {'mp': 'Jack Lopresti MP',
#      'name': 'Filton and Bradley Stoke',
#      'ons_code': 'E14000702',
#      'signature_count': 10121},
#     {'mp': 'Mike Freer MP',
#      'name': 'Finchley and Golders Green',
#      'ons_code': 'E14000703',
#      'signature_count': 19096},
#     {'mp': 'Damian Collins MP',
#      'name': 'Folkestone and Hythe',
#      'ons_code': 'E14000704',
#      'signature_count': 8227},
#     {'mp': 'Rt Hon Mark Harper MP',
#      'name': 'Forest of Dean',
#      'ons_code': 'E14000705',
#      'signature_count': 6493},
#     {'mp': 'Elisha McCallion MP',
#      'name': 'Foyle',
#      'ons_code': 'N06000008',
#      'signature_count': 10181},
#     {'mp': 'Mark Menzies MP',
#      'name': 'Fylde',
#      'ons_code': 'E14000706',
#      'signature_count': 5450},
#     {'mp': 'Rt Hon Sir Edward Leigh MP',
#      'name': 'Gainsborough',
#      'ons_code': 'E14000707',
#      'signature_count': 5075},
#     {'mp': 'Maria Eagle MP',
#      'name': 'Garston and Halewood',
#      'ons_code': 'E14000708',
#      'signature_count': 7869},
#     {'mp': 'Ian Mearns MP',
#      'name': 'Gateshead',
#      'ons_code': 'E14000709',
#      'signature_count': 5742},
#     {'mp': 'Vernon Coaker MP',
#      'name': 'Gedling',
#      'ons_code': 'E14000710',
#      'signature_count': 7202},
#     {'mp': 'Rehman Chishti MP',
#      'name': 'Gillingham and Rainham',
#      'ons_code': 'E14000711',
#      'signature_count': 4749},
#     {'mp': 'Richard Graham MP',
#      'name': 'Gloucester',
#      'ons_code': 'E14000712',
#      'signature_count': 6683},
#     {'mp': 'Caroline Dinenage MP',
#      'name': 'Gosport',
#      'ons_code': 'E14000713',
#      'signature_count': 4911},
#     {'mp': 'Tonia Antoniazzi MP',
#      'name': 'Gower',
#      'ons_code': 'W07000046',
#      'signature_count': 6513},
#     {'mp': 'Nick Boles MP',
#      'name': 'Grantham and Stamford',
#      'ons_code': 'E14000714',
#      'signature_count': 6880},
#     {'mp': 'Adam Holloway MP',
#      'name': 'Gravesham',
#      'ons_code': 'E14000715',
#      'signature_count': 4896},
#     {'mp': 'Melanie Onn MP',
#      'name': 'Great Grimsby',
#      'ons_code': 'E14000716',
#      'signature_count': 2259},
#     {'mp': 'Rt Hon Brandon Lewis MP',
#      'name': 'Great Yarmouth',
#      'ons_code': 'E14000717',
#      'signature_count': 3127},
#     {'mp': 'Matthew Pennycook MP',
#      'name': 'Greenwich and Woolwich',
#      'ons_code': 'E14000718',
#      'signature_count': 18539},
#     {'mp': 'Rt Hon Anne Milton MP',
#      'name': 'Guildford',
#      'ons_code': 'E14000719',
#      'signature_count': 15620},
#     {'mp': 'Rt Hon Diane Abbott MP',
#      'name': 'Hackney North and Stoke Newington',
#      'ons_code': 'E14000720',
#      'signature_count': 26849},
#     {'mp': 'Meg Hillier MP',
#      'name': 'Hackney South and Shoreditch',
#      'ons_code': 'E14000721',
#      'signature_count': 25685},
#     {'mp': 'James Morris MP',
#      'name': 'Halesowen and Rowley Regis',
#      'ons_code': 'E14000722',
#      'signature_count': 3603},
#     {'mp': 'Holly Lynch MP',
#      'name': 'Halifax',
#      'ons_code': 'E14000723',
#      'signature_count': 4256},
#     {'mp': 'Rt Hon David Davis MP',
#      'name': 'Haltemprice and Howden',
#      'ons_code': 'E14000724',
#      'signature_count': 5678},
#     {'mp': 'Derek Twigg MP',
#      'name': 'Halton',
#      'ons_code': 'E14000725',
#      'signature_count': 4827},
#     {'mp': 'Andy Slaughter MP',
#      'name': 'Hammersmith',
#      'ons_code': 'E14000726',
#      'signature_count': 21357},
#     {'mp': 'Tulip Siddiq MP',
#      'name': 'Hampstead and Kilburn',
#      'ons_code': 'E14000727',
#      'signature_count': 27699},
#     {'mp': "Neil O'Brien MP",
#      'name': 'Harborough',
#      'ons_code': 'E14000728',
#      'signature_count': 8050},
#     {'mp': 'Rt Hon Robert Halfon MP',
#      'name': 'Harlow',
#      'ons_code': 'E14000729',
#      'signature_count': 4330},
#     {'mp': 'Andrew Jones MP',
#      'name': 'Harrogate and Knaresborough',
#      'ons_code': 'E14000730',
#      'signature_count': 10749},
#     {'mp': 'Bob Blackman MP',
#      'name': 'Harrow East',
#      'ons_code': 'E14000731',
#      'signature_count': 6954},
#     {'mp': 'Gareth Thomas MP',
#      'name': 'Harrow West',
#      'ons_code': 'E14000732',
#      'signature_count': 9099},
#     {'mp': 'Mike Hill MP',
#      'name': 'Hartlepool',
#      'ons_code': 'E14000733',
#      'signature_count': 2623},
#     {'mp': 'Sir Bernard Jenkin MP',
#      'name': 'Harwich and North Essex',
#      'ons_code': 'E14000734',
#      'signature_count': 7198},
#     {'mp': 'Rt Hon Amber Rudd MP',
#      'name': 'Hastings and Rye',
#      'ons_code': 'E14000735',
#      'signature_count': 9863},
#     {'mp': 'Alan Mak MP',
#      'name': 'Havant',
#      'ons_code': 'E14000736',
#      'signature_count': 5513},
#     {'mp': 'Rt Hon John McDonnell MP',
#      'name': 'Hayes and Harlington',
#      'ons_code': 'E14000737',
#      'signature_count': 4978},
#     {'mp': 'Mr William Wragg MP',
#      'name': 'Hazel Grove',
#      'ons_code': 'E14000738',
#      'signature_count': 7171},
#     {'mp': 'Rt Hon Sir Mike Penning MP',
#      'name': 'Hemel Hempstead',
#      'ons_code': 'E14000739',
#      'signature_count': 8566},
#     {'mp': 'Jon Trickett MP',
#      'name': 'Hemsworth',
#      'ons_code': 'E14000740',
#      'signature_count': 3442},
#     {'mp': 'Dr Matthew Offord MP',
#      'name': 'Hendon',
#      'ons_code': 'E14000741',
#      'signature_count': 11055},
#     {'mp': 'John Howell MP',
#      'name': 'Henley',
#      'ons_code': 'E14000742',
#      'signature_count': 14343},
#     {'mp': 'Jesse Norman MP',
#      'name': 'Hereford and South Herefordshire',
#      'ons_code': 'E14000743',
#      'signature_count': 6903},
#     {'mp': 'Mr Mark Prisk MP',
#      'name': 'Hertford and Stortford',
#      'ons_code': 'E14000744',
#      'signature_count': 12491},
#     {'mp': 'Oliver Dowden MP',
#      'name': 'Hertsmere',
#      'ons_code': 'E14000745',
#      'signature_count': 9237},
#     {'mp': 'Guy Opperman MP',
#      'name': 'Hexham',
#      'ons_code': 'E14000746',
#      'signature_count': 8160},
#     {'mp': 'Liz McInnes MP',
#      'name': 'Heywood and Middleton',
#      'ons_code': 'E14000747',
#      'signature_count': 4367},
#     {'mp': 'Ruth George MP',
#      'name': 'High Peak',
#      'ons_code': 'E14000748',
#      'signature_count': 9403},
#     {'mp': 'Bim Afolami MP',
#      'name': 'Hitchin and Harpenden',
#      'ons_code': 'E14000749',
#      'signature_count': 15756},
#     {'mp': 'Rt Hon Keir Starmer MP',
#      'name': 'Holborn and St Pancras',
#      'ons_code': 'E14000750',
#      'signature_count': 26831},
#     {'mp': 'Julia Lopez MP',
#      'name': 'Hornchurch and Upminster',
#      'ons_code': 'E14000751',
#      'signature_count': 5397},
#     {'mp': 'Catherine West MP',
#      'name': 'Hornsey and Wood Green',
#      'ons_code': 'E14000752',
#      'signature_count': 30712},
#     {'mp': 'Jeremy Quin MP',
#      'name': 'Horsham',
#      'ons_code': 'E14000753',
#      'signature_count': 12015},
#     {'mp': 'Bridget Phillipson MP',
#      'name': 'Houghton and Sunderland South',
#      'ons_code': 'E14000754',
#      'signature_count': 2950},
#     {'mp': 'Peter Kyle MP',
#      'name': 'Hove',
#      'ons_code': 'E14000755',
#      'signature_count': 21757},
#     {'mp': 'Mr Barry Sheerman MP',
#      'name': 'Huddersfield',
#      'ons_code': 'E14000756',
#      'signature_count': 4956},
#     {'mp': 'Mr Jonathan Djanogly MP',
#      'name': 'Huntingdon',
#      'ons_code': 'E14000757',
#      'signature_count': 9984},
#     {'mp': 'Graham P Jones MP',
#      'name': 'Hyndburn',
#      'ons_code': 'E14000758',
#      'signature_count': 2960},
#     {'mp': 'Wes Streeting MP',
#      'name': 'Ilford North',
#      'ons_code': 'E14000759',
#      'signature_count': 7459},
#     {'mp': 'Mike Gapes MP',
#      'name': 'Ilford South',
#      'ons_code': 'E14000760',
#      'signature_count': 6193},
#     {'mp': 'Sandy Martin MP',
#      'name': 'Ipswich',
#      'ons_code': 'E14000761',
#      'signature_count': 7553},
#     {'mp': 'Mr Bob Seely MP',
#      'name': 'Isle of Wight',
#      'ons_code': 'E14000762',
#      'signature_count': 9631},
#     {'mp': 'Rt Hon Jeremy Corbyn MP',
#      'name': 'Islington North',
#      'ons_code': 'E14000763',
#      'signature_count': 25905},
#     {'mp': 'Rt Hon Emily Thornberry MP',
#      'name': 'Islington South and Finsbury',
#      'ons_code': 'E14000764',
#      'signature_count': 22654},
#     {'mp': 'Chris Evans MP',
#      'name': 'Islwyn',
#      'ons_code': 'W07000077',
#      'signature_count': 3074},
#     {'mp': 'Mr Stephen Hepburn MP',
#      'name': 'Jarrow',
#      'ons_code': 'E14000765',
#      'signature_count': 3888},
#     {'mp': 'John Grogan MP',
#      'name': 'Keighley',
#      'ons_code': 'E14000766',
#      'signature_count': 6967},
#     {'mp': 'Rt Hon Jeremy Wright QC MP',
#      'name': 'Kenilworth and Southam',
#      'ons_code': 'E14000767',
#      'signature_count': 9894},
#     {'mp': 'Emma Dent Coad MP',
#      'name': 'Kensington',
#      'ons_code': 'E14000768',
#      'signature_count': 20577},
#     {'mp': 'Mr Philip Hollobone MP',
#      'name': 'Kettering',
#      'ons_code': 'E14000769',
#      'signature_count': 5604},
#     {'mp': 'Rt Hon Sir Edward Davey MP',
#      'name': 'Kingston and Surbiton',
#      'ons_code': 'E14000770',
#      'signature_count': 17598},
#     {'mp': 'Karl Turner MP',
#      'name': 'Kingston upon Hull East',
#      'ons_code': 'E14000771',
#      'signature_count': 2217},
#     {'mp': 'Diana Johnson MP',
#      'name': 'Kingston upon Hull North',
#      'ons_code': 'E14000772',
#      'signature_count': 4545},
#     {'mp': 'Emma Hardy MP',
#      'name': 'Kingston upon Hull West and Hessle',
#      'ons_code': 'E14000773',
#      'signature_count': 3119},
#     {'mp': 'Chris Skidmore MP',
#      'name': 'Kingswood',
#      'ons_code': 'E14000774',
#      'signature_count': 6700},
#     {'mp': 'Rt Hon George Howarth MP',
#      'name': 'Knowsley',
#      'ons_code': 'E14000775',
#      'signature_count': 5120},
#     {'mp': 'Rt Hon Sir Jeffrey M. Donaldson MP',
#      'name': 'Lagan Valley',
#      'ons_code': 'N06000009',
#      'signature_count': 6947},
#     {'mp': 'Cat Smith MP',
#      'name': 'Lancaster and Fleetwood',
#      'ons_code': 'E14000776',
#      'signature_count': 7756},
#     {'mp': 'Rt Hon Hilary Benn MP',
#      'name': 'Leeds Central',
#      'ons_code': 'E14000777',
#      'signature_count': 9486},
#     {'mp': 'Richard Burgon MP',
#      'name': 'Leeds East',
#      'ons_code': 'E14000778',
#      'signature_count': 3708},
#     {'mp': 'Fabian Hamilton MP',
#      'name': 'Leeds North East',
#      'ons_code': 'E14000779',
#      'signature_count': 12629},
#     {'mp': 'Alex Sobel MP',
#      'name': 'Leeds North West',
#      'ons_code': 'E14000780',
#      'signature_count': 11034},
#     {'mp': 'Rachel Reeves MP',
#      'name': 'Leeds West',
#      'ons_code': 'E14000781',
#      'signature_count': 7439},
#     {'mp': 'Rt Hon Keith Vaz MP',
#      'name': 'Leicester East',
#      'ons_code': 'E14000782',
#      'signature_count': 3524},
#     {'mp': 'Jonathan Ashworth MP',
#      'name': 'Leicester South',
#      'ons_code': 'E14000783',
#      'signature_count': 8015},
#     {'mp': 'Liz Kendall MP',
#      'name': 'Leicester West',
#      'ons_code': 'E14000784',
#      'signature_count': 5058},
#     {'mp': 'Jo Platt MP',
#      'name': 'Leigh',
#      'ons_code': 'E14000785',
#      'signature_count': 4185},
#     {'mp': 'Maria Caulfield MP',
#      'name': 'Lewes',
#      'ons_code': 'E14000786',
#      'signature_count': 13427},
#     {'mp': 'Janet Daby MP',
#      'name': 'Lewisham East',
#      'ons_code': 'E14000787',
#      'signature_count': 12943},
#     {'mp': 'Ellie Reeves MP',
#      'name': 'Lewisham West and Penge',
#      'ons_code': 'E14000788',
#      'signature_count': 19052},
#     {'mp': 'Vicky Foxcroft MP',
#      'name': 'Lewisham, Deptford',
#      'ons_code': 'E14000789',
#      'signature_count': 23614},
#     {'mp': 'John Cryer MP',
#      'name': 'Leyton and Wanstead',
#      'ons_code': 'E14000790',
#      'signature_count': 14488},
#     {'mp': 'Michael Fabricant MP',
#      'name': 'Lichfield',
#      'ons_code': 'E14000791',
#      'signature_count': 6369},
#     {'mp': 'Karen Lee MP',
#      'name': 'Lincoln',
#      'ons_code': 'E14000792',
#      'signature_count': 7183},
#     {'mp': 'Dame Louise Ellman MP',
#      'name': 'Liverpool, Riverside',
#      'ons_code': 'E14000793',
#      'signature_count': 14283},
#     {'mp': 'Dan Carden MP',
#      'name': 'Liverpool, Walton',
#      'ons_code': 'E14000794',
#      'signature_count': 4464},
#     {'mp': 'Luciana Berger MP',
#      'name': 'Liverpool, Wavertree',
#      'ons_code': 'E14000795',
#      'signature_count': 8661},
#     {'mp': 'Stephen Twigg MP',
#      'name': 'Liverpool, West Derby',
#      'ons_code': 'E14000796',
#      'signature_count': 5184},
#     {'mp': 'Nia Griffith MP',
#      'name': 'Llanelli',
#      'ons_code': 'W07000045',
#      'signature_count': 3902},
#     {'mp': 'Rt Hon Nicky Morgan MP',
#      'name': 'Loughborough',
#      'ons_code': 'E14000797',
#      'signature_count': 8293},
#     {'mp': 'Victoria Atkins MP',
#      'name': 'Louth and Horncastle',
#      'ons_code': 'E14000798',
#      'signature_count': 4018},
#     {'mp': 'Rt Hon Philip Dunne MP',
#      'name': 'Ludlow',
#      'ons_code': 'E14000799',
#      'signature_count': 6463},
#     {'mp': 'Kelvin Hopkins MP',
#      'name': 'Luton North',
#      'ons_code': 'E14000800',
#      'signature_count': 3836},
#     {'mp': 'Mr Gavin Shuker MP',
#      'name': 'Luton South',
#      'ons_code': 'E14000801',
#      'signature_count': 4787},
#     {'mp': 'David Rutley MP',
#      'name': 'Macclesfield',
#      'ons_code': 'E14000802',
#      'signature_count': 10566},
#     {'mp': 'Rt Hon Theresa May MP',
#      'name': 'Maidenhead',
#      'ons_code': 'E14000803',
#      'signature_count': 12736},
#     {'mp': 'Mrs Helen Grant MP',
#      'name': 'Maidstone and The Weald',
#      'ons_code': 'E14000804',
#      'signature_count': 8391},
#     {'mp': 'Yvonne Fovargue MP',
#      'name': 'Makerfield',
#      'ons_code': 'E14000805',
#      'signature_count': 3601},
#     {'mp': 'Rt Hon John Whittingdale MP',
#      'name': 'Maldon',
#      'ons_code': 'E14000806',
#      'signature_count': 5272},
#     {'mp': 'Lucy Powell MP',
#      'name': 'Manchester Central',
#      'ons_code': 'E14000807',
#      'signature_count': 14098},
#     {'mp': 'Afzal Khan MP',
#      'name': 'Manchester, Gorton',
#      'ons_code': 'E14000808',
#      'signature_count': 9732},
#     {'mp': 'Jeff Smith MP',
#      'name': 'Manchester, Withington',
#      'ons_code': 'E14000809',
#      'signature_count': 19012},
#     {'mp': 'Ben Bradley MP',
#      'name': 'Mansfield',
#      'ons_code': 'E14000810',
#      'signature_count': 3369},
#     {'mp': 'Neil Gray MP',
#      'name': 'Airdrie and Shotts',
#      'ons_code': 'S14000003',
#      'signature_count': 4733},
#     {'mp': 'George Hollingbery MP',
#      'name': 'Meon Valley',
#      'ons_code': 'E14000811',
#      'signature_count': 8046},
#     {'mp': 'Rt Hon Dame Caroline Spelman MP',
#      'name': 'Meriden',
#      'ons_code': 'E14000812',
#      'signature_count': 6771},
#     {'mp': 'Gerald Jones MP',
#      'name': 'Merthyr Tydfil and Rhymney',
#      'ons_code': 'W07000071',
#      'signature_count': 2619},
#     {'mp': 'Ms Nadine Dorries MP',
#      'name': 'Mid Bedfordshire',
#      'ons_code': 'E14000813',
#      'signature_count': 9194},
#     {'mp': 'Mrs Pauline Latham MP',
#      'name': 'Mid Derbyshire',
#      'ons_code': 'E14000814',
#      'signature_count': 7025},
#     {'mp': 'Michael Tomlinson MP',
#      'name': 'Mid Dorset and North Poole',
#      'ons_code': 'E14000815',
#      'signature_count': 6799},
#     {'mp': 'George Freeman MP',
#      'name': 'Mid Norfolk',
#      'ons_code': 'E14000816',
#      'signature_count': 6834},
#     {'mp': 'Rt Hon Sir Nicholas Soames MP',
#      'name': 'Mid Sussex',
#      'ons_code': 'E14000817',
#      'signature_count': 13072},
#     {'mp': 'Francie Molloy MP',
#      'name': 'Mid Ulster',
#      'ons_code': 'N06000010',
#      'signature_count': 4990},
#     {'mp': 'Nigel Huddleston MP',
#      'name': 'Mid Worcestershire',
#      'ons_code': 'E14000818',
#      'signature_count': 6655},
#     {'mp': 'Andy McDonald MP',
#      'name': 'Middlesbrough',
#      'ons_code': 'E14000819',
#      'signature_count': 2804},
#     {'mp': 'Mr Simon Clarke MP',
#      'name': 'Middlesbrough South and East Cleveland',
#      'ons_code': 'E14000820',
#      'signature_count': 3780},
#     {'mp': 'Rt Hon Mark Lancaster MP',
#      'name': 'Milton Keynes North',
#      'ons_code': 'E14000821',
#      'signature_count': 11165},
#     {'mp': 'Iain Stewart MP',
#      'name': 'Milton Keynes South',
#      'ons_code': 'E14000822',
#      'signature_count': 10446},
#     {'mp': 'Siobhain McDonagh MP',
#      'name': 'Mitcham and Morden',
#      'ons_code': 'E14000823',
#      'signature_count': 9709},
#     {'mp': 'Sir Paul Beresford MP',
#      'name': 'Mole Valley',
#      'ons_code': 'E14000824',
#      'signature_count': 12510},
#     {'mp': 'David T. C. Davies MP',
#      'name': 'Monmouth',
#      'ons_code': 'W07000054',
# ...
#      'signature_count': 9565},
#     {'mp': 'Jo Swinson MP',
#      'name': 'East Dunbartonshire',
#      'ons_code': 'S14000018',
#      'signature_count': 12524},
#     {'mp': 'Dr Lisa Cameron MP',
#      'name': 'East Kilbride, Strathaven and Lesmahagow',
#      'ons_code': 'S14000019',
#      'signature_count': 9322},
#     {'mp': 'Bill Grant MP',
#      'name': 'Ayr, Carrick and Cumnock',
#      'ons_code': 'S14000006',
#      'signature_count': 5597},
#     {'mp': 'Martin Whitfield MP',
#      'name': 'East Lothian',
#      'ons_code': 'S14000020',
#      'signature_count': 12402},
#     {'mp': 'Paul Masterton MP',
#      'name': 'East Renfrewshire',
#      'ons_code': 'S14000021',
#      'signature_count': 12053}],
#    'signatures_by_country': [{'code': 'AF',
#      'name': 'Afghanistan',
#      'signature_count': 22},
#     {'code': 'AL', 'name': 'Albania', 'signature_count': 21},
#     {'code': 'DZ', 'name': 'Algeria', 'signature_count': 13},
#     {'code': 'AS', 'name': 'American Samoa', 'signature_count': 4},
#     {'code': 'AD', 'name': 'Andorra', 'signature_count': 43},
#     {'code': 'AO', 'name': 'Angola', 'signature_count': 9},
#     {'code': 'AI', 'name': 'Anguilla', 'signature_count': 15},
#     {'code': 'AG', 'name': 'Antigua and Barbuda', 'signature_count': 23},
#     {'code': 'AR', 'name': 'Argentina', 'signature_count': 163},
#     {'code': 'AM', 'name': 'Armenia', 'signature_count': 7},
#     {'code': 'AW', 'name': 'Aruba', 'signature_count': 5},
#     {'code': 'AU', 'name': 'Australia', 'signature_count': 18346},
#     {'code': 'AT', 'name': 'Austria', 'signature_count': 2654},
#     {'code': 'AZ', 'name': 'Azerbaijan', 'signature_count': 14},
#     {'code': 'BH', 'name': 'Bahrain', 'signature_count': 145},
#     {'code': 'BD', 'name': 'Bangladesh', 'signature_count': 23},
#     {'code': 'BB', 'name': 'Barbados', 'signature_count': 74},
#     {'code': 'BY', 'name': 'Belarus', 'signature_count': 8},
#     {'code': 'BE', 'name': 'Belgium', 'signature_count': 4855},
#     {'code': 'BZ', 'name': 'Belize', 'signature_count': 19},
#     {'code': 'BJ', 'name': 'Benin', 'signature_count': 4},
#     {'code': 'BM', 'name': 'Bermuda', 'signature_count': 410},
#     {'code': 'BT', 'name': 'Bhutan', 'signature_count': 4},
#     {'code': 'BO', 'name': 'Bolivia', 'signature_count': 22},
#     {'code': 'BQ', 'name': 'Bonaire/St Eustatius/Saba', 'signature_count': 6},
#     {'code': 'BA', 'name': 'Bosnia and Herzegovina', 'signature_count': 20},
#     {'code': 'BW', 'name': 'Botswana', 'signature_count': 39},
#     {'code': 'BR', 'name': 'Brazil', 'signature_count': 412},
#     {'code': 'BAT',
#      'name': 'British Antarctic Territory',
#      'signature_count': 13},
#     {'code': 'IO',
#      'name': 'British Indian Ocean Territory',
#      'signature_count': 7},
#     {'code': 'VG', 'name': 'British Virgin Islands', 'signature_count': 85},
#     {'code': 'BN', 'name': 'Brunei', 'signature_count': 56},
#     {'code': 'BG', 'name': 'Bulgaria', 'signature_count': 522},
#     {'code': 'BF', 'name': 'Burkina Faso', 'signature_count': 5},
#     {'code': 'MM', 'name': 'Burma', 'signature_count': 48},
#     {'code': 'BI', 'name': 'Burundi', 'signature_count': 5},
#     {'code': 'KH', 'name': 'Cambodia', 'signature_count': 84},
#     {'code': 'CM', 'name': 'Cameroon', 'signature_count': 5},
#     {'code': 'CA', 'name': 'Canada', 'signature_count': 10437},
#     {'code': 'CV', 'name': 'Cape Verde', 'signature_count': 5},
#     {'code': 'KY', 'name': 'Cayman Islands', 'signature_count': 192},
#     {'code': 'CF', 'name': 'Central African Republic', 'signature_count': 2},
#     {'code': 'TD', 'name': 'Chad', 'signature_count': 4},
#     {'code': 'CL', 'name': 'Chile', 'signature_count': 157},
#     {'code': 'CN', 'name': 'China', 'signature_count': 522},
#     {'code': 'CO', 'name': 'Colombia', 'signature_count': 141},
#     {'code': 'KM', 'name': 'Comoros', 'signature_count': 2},
#     {'code': 'CG', 'name': 'Congo', 'signature_count': 2},
#     {'code': 'CD',
#      'name': 'Congo (Democratic Republic)',
#      'signature_count': 10},
#     {'code': 'CR', 'name': 'Costa Rica', 'signature_count': 44},
#     {'code': 'HR', 'name': 'Croatia', 'signature_count': 103},
#     {'code': 'CU', 'name': 'Cuba', 'signature_count': 14},
#     {'code': 'CW', 'name': 'Curaçao', 'signature_count': 6},
#     {'code': 'CY', 'name': 'Cyprus', 'signature_count': 1358},
#     {'code': 'CZ', 'name': 'Czechia', 'signature_count': 932},
#     {'code': 'DK', 'name': 'Denmark', 'signature_count': 2726},
#     {'code': 'DJ', 'name': 'Djibouti', 'signature_count': 1},
#     {'code': 'DM', 'name': 'Dominica', 'signature_count': 4},
#     {'code': 'DO', 'name': 'Dominican Republic', 'signature_count': 17},
#     {'code': 'TL', 'name': 'East Timor', 'signature_count': 13},
#     {'code': 'EC', 'name': 'Ecuador', 'signature_count': 51},
#     {'code': 'EG', 'name': 'Egypt', 'signature_count': 160},
#     {'code': 'SV', 'name': 'El Salvador', 'signature_count': 9},
#     {'code': 'GQ', 'name': 'Equatorial Guinea', 'signature_count': 2},
#     {'code': 'ER', 'name': 'Eritrea', 'signature_count': 2},
#     {'code': 'EE', 'name': 'Estonia', 'signature_count': 113},
#     {'code': 'SZ', 'name': 'Eswatini', 'signature_count': 14},
#     {'code': 'ET', 'name': 'Ethiopia', 'signature_count': 35},
#     {'code': 'FK', 'name': 'Falkland Islands', 'signature_count': 29},
#     {'code': 'FJ', 'name': 'Fiji', 'signature_count': 23},
#     {'code': 'FI', 'name': 'Finland', 'signature_count': 1224},
#     {'code': 'FR', 'name': 'France', 'signature_count': 42677},
#     {'code': 'GF', 'name': 'French Guiana', 'signature_count': 40},
#     {'code': 'PF', 'name': 'French Polynesia', 'signature_count': 16},
#     {'code': 'GA', 'name': 'Gabon', 'signature_count': 12},
#     {'code': 'GE', 'name': 'Georgia', 'signature_count': 24},
#     {'code': 'DE', 'name': 'Germany', 'signature_count': 19591},
#     {'code': 'GH', 'name': 'Ghana', 'signature_count': 43},
#     {'code': 'GI', 'name': 'Gibraltar', 'signature_count': 4413},
#     {'code': 'GR', 'name': 'Greece', 'signature_count': 1652},
#     {'code': 'GD', 'name': 'Grenada', 'signature_count': 17},
#     {'code': 'GP', 'name': 'Guadeloupe', 'signature_count': 14},
#     {'code': 'GT', 'name': 'Guatemala', 'signature_count': 21},
#     {'code': 'GG', 'name': 'Guernsey', 'signature_count': 1031},
#     {'code': 'GN', 'name': 'Guinea', 'signature_count': 4},
#     {'code': 'GW', 'name': 'Guinea-Bissau', 'signature_count': 3},
#     {'code': 'GY', 'name': 'Guyana', 'signature_count': 11},
#     {'code': 'HT', 'name': 'Haiti', 'signature_count': 2},
#     {'code': 'HN', 'name': 'Honduras', 'signature_count': 9},
#     {'code': 'HK', 'name': 'Hong Kong', 'signature_count': 3031},
#     {'code': 'HU', 'name': 'Hungary', 'signature_count': 447},
#     {'code': 'IS', 'name': 'Iceland', 'signature_count': 123},
#     {'code': 'IN', 'name': 'India', 'signature_count': 384},
#     {'code': 'ID', 'name': 'Indonesia', 'signature_count': 227},
#     {'code': 'IR', 'name': 'Iran', 'signature_count': 19},
#     {'code': 'IQ', 'name': 'Iraq', 'signature_count': 24},
#     {'code': 'IE', 'name': 'Ireland', 'signature_count': 9181},
#     {'code': 'IM', 'name': 'Isle of Man', 'signature_count': 1165},
#     {'code': 'IL', 'name': 'Israel', 'signature_count': 393},
#     {'code': 'IT', 'name': 'Italy', 'signature_count': 5583},
#     {'code': 'CI', 'name': 'Ivory Coast', 'signature_count': 8},
#     {'code': 'JM', 'name': 'Jamaica', 'signature_count': 51},
#     {'code': 'JP', 'name': 'Japan', 'signature_count': 1419},
#     {'code': 'JE', 'name': 'Jersey', 'signature_count': 1392},
#     {'code': 'JO', 'name': 'Jordan', 'signature_count': 76},
#     {'code': 'KZ', 'name': 'Kazakhstan', 'signature_count': 24},
#     {'code': 'KE', 'name': 'Kenya', 'signature_count': 266},
#     {'code': 'KI', 'name': 'Kiribati', 'signature_count': 3},
#     {'code': 'XK', 'name': 'Kosovo', 'signature_count': 14},
#     {'code': 'KW', 'name': 'Kuwait', 'signature_count': 70},
#     {'code': 'KG', 'name': 'Kyrgyzstan', 'signature_count': 6},
#     {'code': 'LA', 'name': 'Laos', 'signature_count': 33},
#     {'code': 'LV', 'name': 'Latvia', 'signature_count': 81},
#     {'code': 'LB', 'name': 'Lebanon', 'signature_count': 100},
#     {'code': 'LS', 'name': 'Lesotho', 'signature_count': 4},
#     {'code': 'LR', 'name': 'Liberia', 'signature_count': 4},
#     {'code': 'LY', 'name': 'Libya', 'signature_count': 10},
#     {'code': 'LI', 'name': 'Liechtenstein', 'signature_count': 8},
#     {'code': 'LT', 'name': 'Lithuania', 'signature_count': 76},
#     {'code': 'LU', 'name': 'Luxembourg', 'signature_count': 1606},
#     {'code': 'MO', 'name': 'Macao', 'signature_count': 27},
#     {'code': 'MG', 'name': 'Madagascar', 'signature_count': 12},
#     {'code': 'MW', 'name': 'Malawi', 'signature_count': 56},
#     {'code': 'MY', 'name': 'Malaysia', 'signature_count': 495},
#     {'code': 'MV', 'name': 'Maldives', 'signature_count': 11},
#     {'code': 'ML', 'name': 'Mali', 'signature_count': 4},
#     {'code': 'MT', 'name': 'Malta', 'signature_count': 903},
#     {'code': 'MH', 'name': 'Marshall Islands', 'signature_count': 3},
#     {'code': 'MQ', 'name': 'Martinique', 'signature_count': 11},
#     {'code': 'MR', 'name': 'Mauritania', 'signature_count': 3},
#     {'code': 'MU', 'name': 'Mauritius', 'signature_count': 75},
#     {'code': 'YT', 'name': 'Mayotte', 'signature_count': 4},
#     {'code': 'MX', 'name': 'Mexico', 'signature_count': 308},
#     {'code': 'FM', 'name': 'Micronesia', 'signature_count': 4},
#     {'code': 'MD', 'name': 'Moldova', 'signature_count': 9},
#     {'code': 'MC', 'name': 'Monaco', 'signature_count': 143},
#     {'code': 'MN', 'name': 'Mongolia', 'signature_count': 15},
#     {'code': 'ME', 'name': 'Montenegro', 'signature_count': 11},
#     {'code': 'MS', 'name': 'Montserrat', 'signature_count': 15},
#     {'code': 'MA', 'name': 'Morocco', 'signature_count': 53},
#     {'code': 'MZ', 'name': 'Mozambique', 'signature_count': 23},
#     {'code': 'NA', 'name': 'Namibia', 'signature_count': 24},
#     {'code': 'NR', 'name': 'Nauru', 'signature_count': 3},
#     {'code': 'NP', 'name': 'Nepal', 'signature_count': 34},
#     {'code': 'NL', 'name': 'Netherlands', 'signature_count': 9446},
#     {'code': 'NC', 'name': 'New Caledonia', 'signature_count': 20},
#     {'code': 'NZ', 'name': 'New Zealand', 'signature_count': 6802},
#     {'code': 'NI', 'name': 'Nicaragua', 'signature_count': 13},
#     {'code': 'NE', 'name': 'Niger', 'signature_count': 4},
#     {'code': 'NG', 'name': 'Nigeria', 'signature_count': 81},
#     {'code': 'KP', 'name': 'North Korea', 'signature_count': 32},
#     {'code': 'MK', 'name': 'North Macedonia', 'signature_count': 17},
#     {'code': 'NO', 'name': 'Norway', 'signature_count': 1726},
#     {'code': 'OM', 'name': 'Oman', 'signature_count': 158},
#     {'code': 'PK', 'name': 'Pakistan', 'signature_count': 72},
#     {'code': 'PW', 'name': 'Palau', 'signature_count': 2},
#     {'code': 'PA', 'name': 'Panama', 'signature_count': 30},
#     {'code': 'PG', 'name': 'Papua New Guinea', 'signature_count': 8},
#     {'code': 'PY', 'name': 'Paraguay', 'signature_count': 6},
#     {'code': 'PE', 'name': 'Peru', 'signature_count': 111},
#     {'code': 'PH', 'name': 'Philippines', 'signature_count': 216},
#     {'code': 'PN', 'name': 'Pitcairn Island', 'signature_count': 3},
#     {'code': 'PL', 'name': 'Poland', 'signature_count': 929},
#     {'code': 'PT', 'name': 'Portugal', 'signature_count': 2660},
#     {'code': 'QA', 'name': 'Qatar', 'signature_count': 343},
#     {'code': 'RO', 'name': 'Romania', 'signature_count': 301},
#     {'code': 'RU', 'name': 'Russia', 'signature_count': 156},
#     {'code': 'RW', 'name': 'Rwanda', 'signature_count': 34},
#     {'code': 'RE', 'name': 'Réunion', 'signature_count': 44},
#     {'code': 'BL', 'name': 'Saint-Barthélemy', 'signature_count': 17},
#     {'code': 'WS', 'name': 'Samoa', 'signature_count': 6},
#     {'code': 'SM', 'name': 'San Marino', 'signature_count': 9},
#     {'code': 'ST', 'name': 'Sao Tome and Principe', 'signature_count': 7},
#     {'code': 'SA', 'name': 'Saudi Arabia', 'signature_count': 174},
#     {'code': 'SN', 'name': 'Senegal', 'signature_count': 18},
#     {'code': 'RS', 'name': 'Serbia', 'signature_count': 56},
#     {'code': 'SC', 'name': 'Seychelles', 'signature_count': 20},
#     {'code': 'SL', 'name': 'Sierra Leone', 'signature_count': 10},
#     {'code': 'SG', 'name': 'Singapore', 'signature_count': 2148},
#     {'code': 'SK', 'name': 'Slovakia', 'signature_count': 182},
#     {'code': 'SI', 'name': 'Slovenia', 'signature_count': 111},
#     {'code': 'SB', 'name': 'Solomon Islands', 'signature_count': 6},
#     {'code': 'SO', 'name': 'Somalia', 'signature_count': 8},
#     {'code': 'ZA', 'name': 'South Africa', 'signature_count': 2171},
#     {'code': 'GS',
#      'name': 'South Georgia and the South Sandwich Islands',
#      'signature_count': 7},
#     {'code': 'KR', 'name': 'South Korea', 'signature_count': 220},
#     {'code': 'SS', 'name': 'South Sudan', 'signature_count': 13},
#     {'code': 'ES', 'name': 'Spain', 'signature_count': 24206},
#     {'code': 'LK', 'name': 'Sri Lanka', 'signature_count': 86},
#     {'code': 'SH',
#      'name': 'St Helena, Ascension and Tristan da Cunha',
#      'signature_count': 24},
#     {'code': 'KN', 'name': 'St Kitts and Nevis', 'signature_count': 19},
#     {'code': 'LC', 'name': 'St Lucia', 'signature_count': 29},
#     {'code': 'SX', 'name': 'St Maarten', 'signature_count': 22},
#     {'code': 'MF', 'name': 'St Martin', 'signature_count': 15},
#     {'code': 'PM', 'name': 'St Pierre & Miquelon', 'signature_count': 6},
#     {'code': 'VC', 'name': 'St Vincent', 'signature_count': 12},
#     {'code': 'SD', 'name': 'Sudan', 'signature_count': 20},
#     {'code': 'SR', 'name': 'Suriname', 'signature_count': 4},
#     {'code': 'SE', 'name': 'Sweden', 'signature_count': 3735},
#     {'code': 'CH', 'name': 'Switzerland', 'signature_count': 6117},
#     {'code': 'SY', 'name': 'Syria', 'signature_count': 11},
#     {'code': 'TW', 'name': 'Taiwan', 'signature_count': 189},
#     {'code': 'TJ', 'name': 'Tajikistan', 'signature_count': 8},
#     {'code': 'TZ', 'name': 'Tanzania', 'signature_count': 84},
#     {'code': 'TH', 'name': 'Thailand', 'signature_count': 1033},
#     {'code': 'BS', 'name': 'The Bahamas', 'signature_count': 40},
#     {'code': 'GM', 'name': 'The Gambia', 'signature_count': 15},
#     {'code': 'PS',
#      'name': 'The Occupied Palestinian Territories',
#      'signature_count': 24},
#     {'code': 'TG', 'name': 'Togo', 'signature_count': 15},
#     {'code': 'TO', 'name': 'Tonga', 'signature_count': 10},
#     {'code': 'TT', 'name': 'Trinidad and Tobago', 'signature_count': 87},
#     {'code': 'TN', 'name': 'Tunisia', 'signature_count': 31},
#     {'code': 'TR', 'name': 'Turkey', 'signature_count': 358},
#     {'code': 'TM', 'name': 'Turkmenistan', 'signature_count': 9},
#     {'code': 'TC', 'name': 'Turks and Caicos Islands', 'signature_count': 54},
#     {'code': 'TV', 'name': 'Tuvalu', 'signature_count': 107},
#     {'code': 'UG', 'name': 'Uganda', 'signature_count': 102},
#     {'code': 'UA', 'name': 'Ukraine', 'signature_count': 100},
#     {'code': 'AE', 'name': 'United Arab Emirates', 'signature_count': 2453},
#     {'code': 'GB', 'name': 'United Kingdom', 'signature_count': 5499546},
#     {'code': 'US', 'name': 'United States', 'signature_count': 23422},
#     {'code': 'UY', 'name': 'Uruguay', 'signature_count': 197},
#     {'code': 'UZ', 'name': 'Uzbekistan', 'signature_count': 122},
#     {'code': 'VU', 'name': 'Vanuatu', 'signature_count': 79},
#     {'code': 'VA', 'name': 'Vatican City', 'signature_count': 68},
#     {'code': 'VE', 'name': 'Venezuela', 'signature_count': 51},
#     {'code': 'VN', 'name': 'Vietnam', 'signature_count': 308},
#     {'code': 'WF', 'name': 'Wallis and Futuna', 'signature_count': 24},
#     {'code': 'EH', 'name': 'Western Sahara', 'signature_count': 21},
#     {'code': 'YE', 'name': 'Yemen', 'signature_count': 12},
#     {'code': 'ZM', 'name': 'Zambia', 'signature_count': 52},
#     {'code': 'ZW', 'name': 'Zimbabwe', 'signature_count': 89}],
#    'state': 'open',
#    'updated_at': '2019-03-26T14:57:25.562Z'},
#   'id': 241584,
#   'type': 'petition'},
#  'links': {'self': 'https://petition.parliament.uk/petitions/241584.json'}}

# %% [markdown]
# The .json() function converts the text into a 'dictionary' called `pet` -  a container of data that is indexed or, in other words, you can look-up data by referencing where it is in the dictionary.  It's a big dictionary!  But hopefully you can see the structure and you can see the keyname:value data more clearly. e.g. `'creator_name': 'John Perrins'.` You can also start to see there is a more complex hierarchy of structure here.  We start with a keyname `data`. In that there is a value called `attributes` and within that there are a number of other names and values.
#
# It means we can work our way through the hierarchy to find what we want.   The example below shows how we can find the name of the person using code.

# %%
petition_data["data"]["attributes"]["creator_name"]
# Out:
# 'Margaret Anne Georgiadou'

# %% [markdown]
# How would you change the code above to get the total number of signatures for the petition

# %% [markdown]
# The code below does the same kind of thing, but digs a bit deeper into the signatures by constituency bit of the data. If you look at the json you'll see that unlike the creator_name value, there is more than one bit of data here. That's where the `[5]` comes in. It effectively says:
#
#   go to `data` and then down to `attributes` and then down to the fifth `signatures_by_constituency` and then show me the value for `mp`. Try changing the value and remember Python starts counting these things at 0 not 1.

# %%
petition_data["data"]["attributes"]["signatures_by_constituency"][34]["mp"]
# Out:
# 'Gavin Newlands MP'

# %% [markdown]
# One are of interesting things to explore around petitions is where people sign from. We can grab that data using the same principle as before.  This time I've used the results to make a new variable called country_data to hold that information.

# %%
country_data = petition_data['data']['attributes']['signatures_by_country']
country_data
# Out:
# [{'code': 'AF', 'name': 'Afghanistan', 'signature_count': 22},
#  {'code': 'AL', 'name': 'Albania', 'signature_count': 21},
#  {'code': 'DZ', 'name': 'Algeria', 'signature_count': 13},
#  {'code': 'AS', 'name': 'American Samoa', 'signature_count': 4},
#  {'code': 'AD', 'name': 'Andorra', 'signature_count': 43},
#  {'code': 'AO', 'name': 'Angola', 'signature_count': 9},
#  {'code': 'AI', 'name': 'Anguilla', 'signature_count': 15},
#  {'code': 'AG', 'name': 'Antigua and Barbuda', 'signature_count': 23},
#  {'code': 'AR', 'name': 'Argentina', 'signature_count': 163},
#  {'code': 'AM', 'name': 'Armenia', 'signature_count': 7},
#  {'code': 'AW', 'name': 'Aruba', 'signature_count': 5},
#  {'code': 'AU', 'name': 'Australia', 'signature_count': 18346},
#  {'code': 'AT', 'name': 'Austria', 'signature_count': 2654},
#  {'code': 'AZ', 'name': 'Azerbaijan', 'signature_count': 14},
#  {'code': 'BH', 'name': 'Bahrain', 'signature_count': 145},
#  {'code': 'BD', 'name': 'Bangladesh', 'signature_count': 23},
#  {'code': 'BB', 'name': 'Barbados', 'signature_count': 74},
#  {'code': 'BY', 'name': 'Belarus', 'signature_count': 8},
#  {'code': 'BE', 'name': 'Belgium', 'signature_count': 4855},
#  {'code': 'BZ', 'name': 'Belize', 'signature_count': 19},
#  {'code': 'BJ', 'name': 'Benin', 'signature_count': 4},
#  {'code': 'BM', 'name': 'Bermuda', 'signature_count': 410},
#  {'code': 'BT', 'name': 'Bhutan', 'signature_count': 4},
#  {'code': 'BO', 'name': 'Bolivia', 'signature_count': 22},
#  {'code': 'BQ', 'name': 'Bonaire/St Eustatius/Saba', 'signature_count': 6},
#  {'code': 'BA', 'name': 'Bosnia and Herzegovina', 'signature_count': 20},
#  {'code': 'BW', 'name': 'Botswana', 'signature_count': 39},
#  {'code': 'BR', 'name': 'Brazil', 'signature_count': 412},
#  {'code': 'BAT', 'name': 'British Antarctic Territory', 'signature_count': 13},
#  {'code': 'IO',
#   'name': 'British Indian Ocean Territory',
#   'signature_count': 7},
#  {'code': 'VG', 'name': 'British Virgin Islands', 'signature_count': 85},
#  {'code': 'BN', 'name': 'Brunei', 'signature_count': 56},
#  {'code': 'BG', 'name': 'Bulgaria', 'signature_count': 522},
#  {'code': 'BF', 'name': 'Burkina Faso', 'signature_count': 5},
#  {'code': 'MM', 'name': 'Burma', 'signature_count': 48},
#  {'code': 'BI', 'name': 'Burundi', 'signature_count': 5},
#  {'code': 'KH', 'name': 'Cambodia', 'signature_count': 84},
#  {'code': 'CM', 'name': 'Cameroon', 'signature_count': 5},
#  {'code': 'CA', 'name': 'Canada', 'signature_count': 10437},
#  {'code': 'CV', 'name': 'Cape Verde', 'signature_count': 5},
#  {'code': 'KY', 'name': 'Cayman Islands', 'signature_count': 192},
#  {'code': 'CF', 'name': 'Central African Republic', 'signature_count': 2},
#  {'code': 'TD', 'name': 'Chad', 'signature_count': 4},
#  {'code': 'CL', 'name': 'Chile', 'signature_count': 157},
#  {'code': 'CN', 'name': 'China', 'signature_count': 522},
#  {'code': 'CO', 'name': 'Colombia', 'signature_count': 141},
#  {'code': 'KM', 'name': 'Comoros', 'signature_count': 2},
#  {'code': 'CG', 'name': 'Congo', 'signature_count': 2},
#  {'code': 'CD', 'name': 'Congo (Democratic Republic)', 'signature_count': 10},
#  {'code': 'CR', 'name': 'Costa Rica', 'signature_count': 44},
#  {'code': 'HR', 'name': 'Croatia', 'signature_count': 103},
#  {'code': 'CU', 'name': 'Cuba', 'signature_count': 14},
#  {'code': 'CW', 'name': 'Curaçao', 'signature_count': 6},
#  {'code': 'CY', 'name': 'Cyprus', 'signature_count': 1358},
#  {'code': 'CZ', 'name': 'Czechia', 'signature_count': 932},
#  {'code': 'DK', 'name': 'Denmark', 'signature_count': 2726},
#  {'code': 'DJ', 'name': 'Djibouti', 'signature_count': 1},
#  {'code': 'DM', 'name': 'Dominica', 'signature_count': 4},
#  {'code': 'DO', 'name': 'Dominican Republic', 'signature_count': 17},
#  {'code': 'TL', 'name': 'East Timor', 'signature_count': 13},
#  {'code': 'EC', 'name': 'Ecuador', 'signature_count': 51},
#  {'code': 'EG', 'name': 'Egypt', 'signature_count': 160},
#  {'code': 'SV', 'name': 'El Salvador', 'signature_count': 9},
#  {'code': 'GQ', 'name': 'Equatorial Guinea', 'signature_count': 2},
#  {'code': 'ER', 'name': 'Eritrea', 'signature_count': 2},
#  {'code': 'EE', 'name': 'Estonia', 'signature_count': 113},
#  {'code': 'SZ', 'name': 'Eswatini', 'signature_count': 14},
#  {'code': 'ET', 'name': 'Ethiopia', 'signature_count': 35},
#  {'code': 'FK', 'name': 'Falkland Islands', 'signature_count': 29},
#  {'code': 'FJ', 'name': 'Fiji', 'signature_count': 23},
#  {'code': 'FI', 'name': 'Finland', 'signature_count': 1224},
#  {'code': 'FR', 'name': 'France', 'signature_count': 42677},
#  {'code': 'GF', 'name': 'French Guiana', 'signature_count': 40},
#  {'code': 'PF', 'name': 'French Polynesia', 'signature_count': 16},
#  {'code': 'GA', 'name': 'Gabon', 'signature_count': 12},
#  {'code': 'GE', 'name': 'Georgia', 'signature_count': 24},
#  {'code': 'DE', 'name': 'Germany', 'signature_count': 19591},
#  {'code': 'GH', 'name': 'Ghana', 'signature_count': 43},
#  {'code': 'GI', 'name': 'Gibraltar', 'signature_count': 4413},
#  {'code': 'GR', 'name': 'Greece', 'signature_count': 1652},
#  {'code': 'GD', 'name': 'Grenada', 'signature_count': 17},
#  {'code': 'GP', 'name': 'Guadeloupe', 'signature_count': 14},
#  {'code': 'GT', 'name': 'Guatemala', 'signature_count': 21},
#  {'code': 'GG', 'name': 'Guernsey', 'signature_count': 1031},
#  {'code': 'GN', 'name': 'Guinea', 'signature_count': 4},
#  {'code': 'GW', 'name': 'Guinea-Bissau', 'signature_count': 3},
#  {'code': 'GY', 'name': 'Guyana', 'signature_count': 11},
#  {'code': 'HT', 'name': 'Haiti', 'signature_count': 2},
#  {'code': 'HN', 'name': 'Honduras', 'signature_count': 9},
#  {'code': 'HK', 'name': 'Hong Kong', 'signature_count': 3031},
#  {'code': 'HU', 'name': 'Hungary', 'signature_count': 447},
#  {'code': 'IS', 'name': 'Iceland', 'signature_count': 123},
#  {'code': 'IN', 'name': 'India', 'signature_count': 384},
#  {'code': 'ID', 'name': 'Indonesia', 'signature_count': 227},
#  {'code': 'IR', 'name': 'Iran', 'signature_count': 19},
#  {'code': 'IQ', 'name': 'Iraq', 'signature_count': 24},
#  {'code': 'IE', 'name': 'Ireland', 'signature_count': 9181},
#  {'code': 'IM', 'name': 'Isle of Man', 'signature_count': 1165},
#  {'code': 'IL', 'name': 'Israel', 'signature_count': 393},
#  {'code': 'IT', 'name': 'Italy', 'signature_count': 5583},
#  {'code': 'CI', 'name': 'Ivory Coast', 'signature_count': 8},
#  {'code': 'JM', 'name': 'Jamaica', 'signature_count': 51},
#  {'code': 'JP', 'name': 'Japan', 'signature_count': 1419},
#  {'code': 'JE', 'name': 'Jersey', 'signature_count': 1392},
#  {'code': 'JO', 'name': 'Jordan', 'signature_count': 76},
#  {'code': 'KZ', 'name': 'Kazakhstan', 'signature_count': 24},
#  {'code': 'KE', 'name': 'Kenya', 'signature_count': 266},
#  {'code': 'KI', 'name': 'Kiribati', 'signature_count': 3},
#  {'code': 'XK', 'name': 'Kosovo', 'signature_count': 14},
#  {'code': 'KW', 'name': 'Kuwait', 'signature_count': 70},
#  {'code': 'KG', 'name': 'Kyrgyzstan', 'signature_count': 6},
#  {'code': 'LA', 'name': 'Laos', 'signature_count': 33},
#  {'code': 'LV', 'name': 'Latvia', 'signature_count': 81},
#  {'code': 'LB', 'name': 'Lebanon', 'signature_count': 100},
#  {'code': 'LS', 'name': 'Lesotho', 'signature_count': 4},
#  {'code': 'LR', 'name': 'Liberia', 'signature_count': 4},
#  {'code': 'LY', 'name': 'Libya', 'signature_count': 10},
#  {'code': 'LI', 'name': 'Liechtenstein', 'signature_count': 8},
#  {'code': 'LT', 'name': 'Lithuania', 'signature_count': 76},
#  {'code': 'LU', 'name': 'Luxembourg', 'signature_count': 1606},
#  {'code': 'MO', 'name': 'Macao', 'signature_count': 27},
#  {'code': 'MG', 'name': 'Madagascar', 'signature_count': 12},
#  {'code': 'MW', 'name': 'Malawi', 'signature_count': 56},
#  {'code': 'MY', 'name': 'Malaysia', 'signature_count': 495},
#  {'code': 'MV', 'name': 'Maldives', 'signature_count': 11},
#  {'code': 'ML', 'name': 'Mali', 'signature_count': 4},
#  {'code': 'MT', 'name': 'Malta', 'signature_count': 903},
#  {'code': 'MH', 'name': 'Marshall Islands', 'signature_count': 3},
#  {'code': 'MQ', 'name': 'Martinique', 'signature_count': 11},
#  {'code': 'MR', 'name': 'Mauritania', 'signature_count': 3},
#  {'code': 'MU', 'name': 'Mauritius', 'signature_count': 75},
#  {'code': 'YT', 'name': 'Mayotte', 'signature_count': 4},
#  {'code': 'MX', 'name': 'Mexico', 'signature_count': 308},
#  {'code': 'FM', 'name': 'Micronesia', 'signature_count': 4},
#  {'code': 'MD', 'name': 'Moldova', 'signature_count': 9},
#  {'code': 'MC', 'name': 'Monaco', 'signature_count': 143},
#  {'code': 'MN', 'name': 'Mongolia', 'signature_count': 15},
#  {'code': 'ME', 'name': 'Montenegro', 'signature_count': 11},
#  {'code': 'MS', 'name': 'Montserrat', 'signature_count': 15},
#  {'code': 'MA', 'name': 'Morocco', 'signature_count': 53},
#  {'code': 'MZ', 'name': 'Mozambique', 'signature_count': 23},
#  {'code': 'NA', 'name': 'Namibia', 'signature_count': 24},
#  {'code': 'NR', 'name': 'Nauru', 'signature_count': 3},
#  {'code': 'NP', 'name': 'Nepal', 'signature_count': 34},
#  {'code': 'NL', 'name': 'Netherlands', 'signature_count': 9446},
#  {'code': 'NC', 'name': 'New Caledonia', 'signature_count': 20},
#  {'code': 'NZ', 'name': 'New Zealand', 'signature_count': 6802},
#  {'code': 'NI', 'name': 'Nicaragua', 'signature_count': 13},
#  {'code': 'NE', 'name': 'Niger', 'signature_count': 4},
#  {'code': 'NG', 'name': 'Nigeria', 'signature_count': 81},
#  {'code': 'KP', 'name': 'North Korea', 'signature_count': 32},
#  {'code': 'MK', 'name': 'North Macedonia', 'signature_count': 17},
#  {'code': 'NO', 'name': 'Norway', 'signature_count': 1726},
#  {'code': 'OM', 'name': 'Oman', 'signature_count': 158},
#  {'code': 'PK', 'name': 'Pakistan', 'signature_count': 72},
#  {'code': 'PW', 'name': 'Palau', 'signature_count': 2},
#  {'code': 'PA', 'name': 'Panama', 'signature_count': 30},
#  {'code': 'PG', 'name': 'Papua New Guinea', 'signature_count': 8},
#  {'code': 'PY', 'name': 'Paraguay', 'signature_count': 6},
#  {'code': 'PE', 'name': 'Peru', 'signature_count': 111},
#  {'code': 'PH', 'name': 'Philippines', 'signature_count': 216},
#  {'code': 'PN', 'name': 'Pitcairn Island', 'signature_count': 3},
#  {'code': 'PL', 'name': 'Poland', 'signature_count': 929},
#  {'code': 'PT', 'name': 'Portugal', 'signature_count': 2660},
#  {'code': 'QA', 'name': 'Qatar', 'signature_count': 343},
#  {'code': 'RO', 'name': 'Romania', 'signature_count': 301},
#  {'code': 'RU', 'name': 'Russia', 'signature_count': 156},
#  {'code': 'RW', 'name': 'Rwanda', 'signature_count': 34},
#  {'code': 'RE', 'name': 'Réunion', 'signature_count': 44},
#  {'code': 'BL', 'name': 'Saint-Barthélemy', 'signature_count': 17},
#  {'code': 'WS', 'name': 'Samoa', 'signature_count': 6},
#  {'code': 'SM', 'name': 'San Marino', 'signature_count': 9},
#  {'code': 'ST', 'name': 'Sao Tome and Principe', 'signature_count': 7},
#  {'code': 'SA', 'name': 'Saudi Arabia', 'signature_count': 174},
#  {'code': 'SN', 'name': 'Senegal', 'signature_count': 18},
#  {'code': 'RS', 'name': 'Serbia', 'signature_count': 56},
#  {'code': 'SC', 'name': 'Seychelles', 'signature_count': 20},
#  {'code': 'SL', 'name': 'Sierra Leone', 'signature_count': 10},
#  {'code': 'SG', 'name': 'Singapore', 'signature_count': 2148},
#  {'code': 'SK', 'name': 'Slovakia', 'signature_count': 182},
#  {'code': 'SI', 'name': 'Slovenia', 'signature_count': 111},
#  {'code': 'SB', 'name': 'Solomon Islands', 'signature_count': 6},
#  {'code': 'SO', 'name': 'Somalia', 'signature_count': 8},
#  {'code': 'ZA', 'name': 'South Africa', 'signature_count': 2171},
#  {'code': 'GS',
#   'name': 'South Georgia and the South Sandwich Islands',
#   'signature_count': 7},
#  {'code': 'KR', 'name': 'South Korea', 'signature_count': 220},
#  {'code': 'SS', 'name': 'South Sudan', 'signature_count': 13},
#  {'code': 'ES', 'name': 'Spain', 'signature_count': 24206},
#  {'code': 'LK', 'name': 'Sri Lanka', 'signature_count': 86},
#  {'code': 'SH',
#   'name': 'St Helena, Ascension and Tristan da Cunha',
#   'signature_count': 24},
#  {'code': 'KN', 'name': 'St Kitts and Nevis', 'signature_count': 19},
#  {'code': 'LC', 'name': 'St Lucia', 'signature_count': 29},
#  {'code': 'SX', 'name': 'St Maarten', 'signature_count': 22},
#  {'code': 'MF', 'name': 'St Martin', 'signature_count': 15},
#  {'code': 'PM', 'name': 'St Pierre & Miquelon', 'signature_count': 6},
#  {'code': 'VC', 'name': 'St Vincent', 'signature_count': 12},
#  {'code': 'SD', 'name': 'Sudan', 'signature_count': 20},
#  {'code': 'SR', 'name': 'Suriname', 'signature_count': 4},
#  {'code': 'SE', 'name': 'Sweden', 'signature_count': 3735},
#  {'code': 'CH', 'name': 'Switzerland', 'signature_count': 6117},
#  {'code': 'SY', 'name': 'Syria', 'signature_count': 11},
#  {'code': 'TW', 'name': 'Taiwan', 'signature_count': 189},
#  {'code': 'TJ', 'name': 'Tajikistan', 'signature_count': 8},
#  {'code': 'TZ', 'name': 'Tanzania', 'signature_count': 84},
#  {'code': 'TH', 'name': 'Thailand', 'signature_count': 1033},
#  {'code': 'BS', 'name': 'The Bahamas', 'signature_count': 40},
#  {'code': 'GM', 'name': 'The Gambia', 'signature_count': 15},
#  {'code': 'PS',
#   'name': 'The Occupied Palestinian Territories',
#   'signature_count': 24},
#  {'code': 'TG', 'name': 'Togo', 'signature_count': 15},
#  {'code': 'TO', 'name': 'Tonga', 'signature_count': 10},
#  {'code': 'TT', 'name': 'Trinidad and Tobago', 'signature_count': 87},
#  {'code': 'TN', 'name': 'Tunisia', 'signature_count': 31},
#  {'code': 'TR', 'name': 'Turkey', 'signature_count': 358},
#  {'code': 'TM', 'name': 'Turkmenistan', 'signature_count': 9},
#  {'code': 'TC', 'name': 'Turks and Caicos Islands', 'signature_count': 54},
#  {'code': 'TV', 'name': 'Tuvalu', 'signature_count': 107},
#  {'code': 'UG', 'name': 'Uganda', 'signature_count': 102},
#  {'code': 'UA', 'name': 'Ukraine', 'signature_count': 100},
#  {'code': 'AE', 'name': 'United Arab Emirates', 'signature_count': 2453},
#  {'code': 'GB', 'name': 'United Kingdom', 'signature_count': 5499546},
#  {'code': 'US', 'name': 'United States', 'signature_count': 23422},
#  {'code': 'UY', 'name': 'Uruguay', 'signature_count': 197},
#  {'code': 'UZ', 'name': 'Uzbekistan', 'signature_count': 122},
#  {'code': 'VU', 'name': 'Vanuatu', 'signature_count': 79},
#  {'code': 'VA', 'name': 'Vatican City', 'signature_count': 68},
#  {'code': 'VE', 'name': 'Venezuela', 'signature_count': 51},
#  {'code': 'VN', 'name': 'Vietnam', 'signature_count': 308},
#  {'code': 'WF', 'name': 'Wallis and Futuna', 'signature_count': 24},
#  {'code': 'EH', 'name': 'Western Sahara', 'signature_count': 21},
#  {'code': 'YE', 'name': 'Yemen', 'signature_count': 12},
#  {'code': 'ZM', 'name': 'Zambia', 'signature_count': 52},
#  {'code': 'ZW', 'name': 'Zimbabwe', 'signature_count': 89}]

# %% [markdown]
# Now that we have that data in a new variable, we can use the pandas library to allow us to do some quick analysis. The first thing we need to do is to convert the data into a pandas **data frame** called` country_df`

# %%
country_df = pd.DataFrame(country_data)
country_df
# Out:
#     code                                  name  signature_count
# 0     AF                           Afghanistan               22
# 1     AL                               Albania               21
# 2     DZ                               Algeria               13
# 3     AS                        American Samoa                4
# 4     AD                               Andorra               43
# 5     AO                                Angola                9
# 6     AI                              Anguilla               15
# 7     AG                   Antigua and Barbuda               23
# 8     AR                             Argentina              163
# 9     AM                               Armenia                7
# 10    AW                                 Aruba                5
# 11    AU                             Australia            18346
# 12    AT                               Austria             2654
# 13    AZ                            Azerbaijan               14
# 14    BH                               Bahrain              145
# 15    BD                            Bangladesh               23
# 16    BB                              Barbados               74
# 17    BY                               Belarus                8
# 18    BE                               Belgium             4855
# 19    BZ                                Belize               19
# 20    BJ                                 Benin                4
# 21    BM                               Bermuda              410
# 22    BT                                Bhutan                4
# 23    BO                               Bolivia               22
# 24    BQ             Bonaire/St Eustatius/Saba                6
# 25    BA                Bosnia and Herzegovina               20
# 26    BW                              Botswana               39
# 27    BR                                Brazil              412
# 28   BAT           British Antarctic Territory               13
# 29    IO        British Indian Ocean Territory                7
# ..   ...                                   ...              ...
# 202   TJ                            Tajikistan                8
# 203   TZ                              Tanzania               84
# 204   TH                              Thailand             1033
# 205   BS                           The Bahamas               40
# 206   GM                            The Gambia               15
# 207   PS  The Occupied Palestinian Territories               24
# 208   TG                                  Togo               15
# 209   TO                                 Tonga               10
# 210   TT                   Trinidad and Tobago               87
# 211   TN                               Tunisia               31
# 212   TR                                Turkey              358
# 213   TM                          Turkmenistan                9
# 214   TC              Turks and Caicos Islands               54
# 215   TV                                Tuvalu              107
# 216   UG                                Uganda              102
# 217   UA                               Ukraine              100
# 218   AE                  United Arab Emirates             2453
# 219   GB                        United Kingdom          5499546
# 220   US                         United States            23422
# 221   UY                               Uruguay              197
# 222   UZ                            Uzbekistan              122
# 223   VU                               Vanuatu               79
# 224   VA                          Vatican City               68
# 225   VE                             Venezuela               51
# 226   VN                               Vietnam              308
# 227   WF                     Wallis and Futuna               24
# 228   EH                        Western Sahara               21
# 229   YE                                 Yemen               12
# 230   ZM                                Zambia               52
# 231   ZW                              Zimbabwe               89
#
# [232 rows x 3 columns]

# %% [markdown]
# You can see the data is now neatly organised as a data frame. But it's organised in alphabetical order. It would be more useful to organise by the number of signatures so we could see where most people signed up from. Pandas has an easy function to do that.

# %%
country_df.sort_values(by=['signature_count'], ascending=False)
# Out:
#     code                      name  signature_count
# 219   GB            United Kingdom          5499546
# 71    FR                    France            42677
# 187   ES                     Spain            24206
# 220   US             United States            23422
# 76    DE                   Germany            19591
# 11    AU                 Australia            18346
# 38    CA                    Canada            10437
# 144   NL               Netherlands             9446
# 96    IE                   Ireland             9181
# 146   NZ               New Zealand             6802
# 199   CH               Switzerland             6117
# 99    IT                     Italy             5583
# 18    BE                   Belgium             4855
# 78    GI                 Gibraltar             4413
# 198   SE                    Sweden             3735
# 89    HK                 Hong Kong             3031
# 55    DK                   Denmark             2726
# 163   PT                  Portugal             2660
# 12    AT                   Austria             2654
# 218   AE      United Arab Emirates             2453
# 183   ZA              South Africa             2171
# 178   SG                 Singapore             2148
# 152   NO                    Norway             1726
# 79    GR                    Greece             1652
# 119   LU                Luxembourg             1606
# 102   JP                     Japan             1419
# 103   JE                    Jersey             1392
# 53    CY                    Cyprus             1358
# 70    FI                   Finland             1224
# 97    IM               Isle of Man             1165
# ..   ...                       ...              ...
# 37    CM                  Cameroon                5
# 35    BI                   Burundi                5
# 33    BF              Burkina Faso                5
# 3     AS            American Samoa                4
# 148   NE                     Niger                4
# 115   LR                   Liberia                4
# 114   LS                   Lesotho                4
# 125   ML                      Mali                4
# 20    BJ                     Benin                4
# 22    BT                    Bhutan                4
# 133   FM                Micronesia                4
# 131   YT                   Mayotte                4
# 42    TD                      Chad                4
# 84    GN                    Guinea                4
# 197   SR                  Suriname                4
# 57    DM                  Dominica                4
# 129   MR                Mauritania                3
# 127   MH          Marshall Islands                3
# 142   NR                     Nauru                3
# 161   PN           Pitcairn Island                3
# 85    GW             Guinea-Bissau                3
# 107   KI                  Kiribati                3
# 41    CF  Central African Republic                2
# 46    KM                   Comoros                2
# 63    GQ         Equatorial Guinea                2
# 47    CG                     Congo                2
# 64    ER                   Eritrea                2
# 155   PW                     Palau                2
# 87    HT                     Haiti                2
# 56    DJ                  Djibouti                1
#
# [232 rows x 3 columns]

# %% [markdown]
# No surprises really. We could make an assumption that places with large expat communities show high return rates. Let's do the same thing but with the constituency data.

# %%
constituency_data = petition_data['data']['attributes']['signatures_by_constituency']
constituency_df = pd.DataFrame(constituency_data)
constituency_df.sort_values(by=['signature_count'], ascending=False)
# Out:
#                                      mp  \
# 292                      Julia Lopez MP
# 459                 Andrew Rosindell MP
# 295               Bridget Phillipson MP
# 544                    Julie Elliott MP
# 191                      Jon Cruddas MP
# 588               Mrs Sharon Hodgson MP
# 559               Jackie Doyle-Price MP
# 56        Rt Hon Dame Margaret Hodge MP
# 116                    Alex Burghart MP
# 493                 Stephen Metcalfe MP
# 231        Rt Hon Dame Eleanor Laing MP
# 213                   Grahame Morris MP
# 446             Rt Hon Mark Francois MP
# 60                     Mr John Baron MP
# 152                   Rebecca Harris MP
# 46                  Sir Graham Brady MP
# 159                       Vicky Ford MP
# 300                    Wes Streeting MP
# 458                  James Duddridge MP
# 350         Rt Hon John Whittingdale MP
# 165         Rt Hon Iain Duncan Smith MP
# 173                    Giles Watling MP
# 270             Rt Hon Robert Halfon MP
# 518                  Sir David Amess MP
# 129                Mr Charles Walker MP
# 524                  Ms Marie Rimmer MP
# 302                     Sandy Martin MP
# 505             Mrs Emma Lewell-Buck MP
# 307               Mr Stephen Hepburn MP
# 301                       Mike Gapes MP
# ..                                  ...
# 40                      Andrew Bowie MP
# 642                    Stewart Hosie MP
# 643                        Chris Law MP
# 49                    Hywel Williams MP
# 71              Emma Little Pengelly MP
# 10                   Mr Paul Sweeney MP
# 25                      Ross Thomson MP
# 69                    Gavin Robinson MP
# 646                  Dr Lisa Cameron MP
# 645                       Jo Swinson MP
# 12          Stewart Malcolm McDonald MP
# 355                        Neil Gray MP
# 27                    Marion Fellows MP
# 33        Rt Hon Alistair Carmichael MP
# 214              Rt Hon Sammy Wilson MP
# 15                       Colin Clark MP
# 318  Rt Hon Sir Jeffrey M. Donaldson MP
# 13                    Chris Stephens MP
# 218              Mr Gregory Campbell MP
# 635                    Kirstene Hair MP
# 37              Rt Hon Ian Blackford MP
# 9                      Patrick Grady MP
# 245                 Elisha McCallion MP
# 240               Michelle Gildernew MP
# 390                      Ian Paisley MP
# 603                 Órfhlaith Begley MP
# 387                     Mickey Brady MP
# 28             Angus Brendan MacNeil MP
# 364                   Francie Molloy MP
# 497                    Chris Hazzard MP
#
#                                          name   ons_code  signature_count
# 292                  Hornchurch and Upminster  E14000751             4412
# 459                                   Romford  E14000900             3613
# 295             Houghton and Sunderland South  E14000754             3086
# 544                        Sunderland Central  E14000982             2672
# 191                      Dagenham and Rainham  E14000657             2383
# 588            Washington and Sunderland West  E14001020             1920
# 559                                  Thurrock  E14000995             1715
# 56                                    Barking  E14000540             1609
# 116                       Brentwood and Ongar  E14000594             1429
# 493          South Basildon and East Thurrock  E14000933             1239
# 231                             Epping Forest  E14000693             1060
# 213                                 Easington  E14000677             1037
# 446                     Rayleigh and Wickford  E14000888             1033
# 60                    Basildon and Billericay  E14000544              968
# 152                              Castle Point  E14000622              882
# 46                   Altrincham and Sale West  E14000532              832
# 159                                Chelmsford  E14000628              761
# 300                              Ilford North  E14000759              745
# 458                Rochford and Southend East  E14000899              728
# 350                                    Maldon  E14000806              633
# 165              Chingford and Woodford Green  E14000634              618
# 173                                   Clacton  E14000642              616
# 270                                    Harlow  E14000729              603
# 518                             Southend West  E14000957              590
# 129                                Broxbourne  E14000606              587
# 524               St Helens South and Whiston  E14000963              586
# 302                                   Ipswich  E14000761              546
# 505                             South Shields  E14000944              533
# 307                                    Jarrow  E14000765              481
# 301                              Ilford South  E14000760              477
# ..                                        ...        ...              ...
# 40          West Aberdeenshire and Kincardine  S14000058               16
# 642                               Dundee East  S14000015               15
# 643                               Dundee West  S14000016               15
# 49                                      Arfon  W07000057               15
# 71                              Belfast South  N06000003               14
# 10                         Glasgow North East  S14000032               14
# 25                             Aberdeen South  S14000002               14
# 69                               Belfast East  N06000001               13
# 646  East Kilbride, Strathaven and Lesmahagow  S14000019               13
# 645                       East Dunbartonshire  S14000018               13
# 12                              Glasgow South  S14000034               12
# 355                        Airdrie and Shotts  S14000003               12
# 27                      Motherwell and Wishaw  S14000047               11
# 33                        Orkney and Shetland  S14000051               11
# 214                               East Antrim  N06000005               11
# 15                                     Gordon  S14000037               11
# 318                              Lagan Valley  N06000009               10
# 13                         Glasgow South West  S14000035               10
# 218                          East Londonderry  N06000006                9
# 635                                     Angus  S14000004                9
# 37                    Ross, Skye and Lochaber  S14000055                9
# 9                               Glasgow North  S14000031                9
# 245                                     Foyle  N06000008                8
# 240                Fermanagh and South Tyrone  N06000007                7
# 390                              North Antrim  N06000012                7
# 603                               West Tyrone  N06000018                7
# 387                          Newry and Armagh  N06000011                7
# 28                       Na h-Eileanan an Iar  S14000027                6
# 364                                Mid Ulster  N06000010                5
# 497                                South Down  N06000015                5
#
# [650 rows x 4 columns]
